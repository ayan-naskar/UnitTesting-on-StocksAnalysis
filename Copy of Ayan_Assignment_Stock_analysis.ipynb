# %% [markdown]
# **Step 1: Load Data**
#
# please remember to upload the file "ITC.NS_historical_data.csv"

# %%
import pandas as pd
import numpy as np

# File path in Google Colab environment
file_path = 'content/ITC.NS_historical_data.csv'
# file_path = 'content/SyntheticTC/1.csv'
# File path for Anil's Physical computer
# file_path = 'D:\DKafka Admin\Outsource\VCP\HistoricalData\ITC.NS_historical_data.csv'

df = pd.read_csv(file_path)

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Adding moving averages to the DataFrame with min_periods=1
df['MA200'] = df['Close'].rolling(window=200, min_periods=1).mean()
df['MA150'] = df['Close'].rolling(window=150, min_periods=1).mean()
df['MA50'] = df['Close'].rolling(window=50, min_periods=1).mean()

# Display the first few rows to ensure it's loaded correctly
print(df.head())
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume  \
# 0 1996-01-01  5.550000  5.600000  5.533333  5.583333   3.255736    985500
# 1 1996-01-02  5.466666  5.566666  5.288888  5.372222   3.132634   7470000
# 2 1996-01-03  5.133333  5.254444  5.101111  5.200000   3.032208  15160500
# 3 1996-01-04  5.200000  5.332222  5.144444  5.297777   3.089224  12397500
# 4 1996-01-05  5.297777  5.277777  5.188888  5.202222   3.033503   5008500
#
#       MA200     MA150      MA50
# 0  5.583333  5.583333  5.583333
# 1  5.477777  5.477777  5.477777
# 2  5.385185  5.385185  5.385185
# 3  5.363333  5.363333  5.363333
# 4  5.331111  5.331111  5.331111

# %% [markdown]
# **Step 2: Filter data for last 3 months**

# %%
# Assuming 'df' is your DataFrame and it's already loaded and 'Date' is in datetime format
pd.set_option('display.max_rows', None)

# Get the last date in the dataset
last_date = df['Date'].max()

# Calculate the date 3 months prior to the last date
three_months_ago = last_date - pd.DateOffset(months=150)

# Filter the DataFrame for the last 3 months
df_last_3_months = df[df['Date'] > three_months_ago]
# df_last_3_months = df_last_3_months[:-1]
# data = {
#         'Date': pd.date_range(start='2022-01-01', periods=10, freq='D'),
#         'Open': [100, 105, 110, 108, 112, 115, 114, 118, 120, 122],
#         'High': [110, 115, 120, 118, 122, 125, 124, 128, 130, 132],
#         'Low': [98, 103, 108, 106, 110, 113, 112, 116, 118, 120],
#         'Close': [105, 110, 115, 113, 118, 120, 119, 123, 125, 128]
#     }

# df_last_3_months=pd.DataFrame(data)
# df_last_3_months['MA200'] = df_last_3_months['Close'].rolling(window=200, min_periods=1).mean()
# df_last_3_months['MA150'] = df_last_3_months['Close'].rolling(window=150, min_periods=1).mean()
# df_last_3_months['MA50'] = df_last_3_months['Close'].rolling(window=50, min_periods=1).mean()

last_date = df['Date'].max()
three_months_ago = last_date - pd.DateOffset(months=1)
df_last_3_months = df[df['Date'] > three_months_ago]
# print(df_last_3_months)  # Just to verify the filtering

# %%
import plotly.graph_objects as go

# Create a candlestick chart for the last 3 months
fig = go.Figure(data=[go.Candlestick(x=df_last_3_months['Date'],
                                     open=df_last_3_months['Open'],
                                     high=df_last_3_months['High'],
                                     low=df_last_3_months['Low'],
                                     close=df_last_3_months['Close'], name="Candlestick")])

# Add MA200
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA200'],
                         mode='lines', name='MA200',
                         line=dict(width=1, color='blue')))

# Add MA150
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA150'],
                         mode='lines', name='MA150',
                         line=dict(width=1, color='red')))

# Add MA50
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA50'],
                         mode='lines', name='MA50',
                         line=dict(width=1, color='green')))

# Customize the layout
fig.update_layout(title='ITC.NS Historical Data (Last 3 Months) with Moving Averages',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False)  # Hide the range slider for a cleaner look

# Show the plot
fig.show()

# %% [markdown]
# # **Utility Functions**
#
# ---

# %% [markdown]
# **Candle diff**
#
# Purpose of the function is to find the number of candles between two candles.
#
# **Limitation** >>  Can't be used for intraday candles

# %%
def candle_diff(date1, date2, df):
    """
    Calculates the number of candles (rows) between two given candle dates in a DataFrame.

    Parameters:
    - date1: The date of the first candle (string or datetime).
    - date2: The date of the second candle (string or datetime).
    - df: DataFrame containing the OHLC data with a 'Date' column.

    Returns:
    - The number of candles between the two given dates, excluding non-trading days.
    """
    # Convert date1 and date2 to datetime if they are not already
    date1 = pd.to_datetime(date1)
    date2 = pd.to_datetime(date2)

    # Ensure date1 is before date2
    if date1 > date2:
        date1, date2 = date2, date1  # Swap the dates if date1 is later than date2

    # Find the indices for the given dates
    index1 = df.index[df['Date'] == date1].tolist()
    index2 = df.index[df['Date'] == date2].tolist()

    # Check if both dates exist in the DataFrame
    if not index1 or not index2:
        return None  # One or both of the dates do not exist in the DataFrame

    # Calculate the difference in indices to find the number of candles between the dates
    candle_count = index2[0] - index1[0]

    return candle_count

# %%
# Sample usage:
# Assuming df is your DataFrame containing the OHLC data
date1 = '2024-01-19'
date2 = '2024-01-22'
diff = candle_diff(date1, date2, df)
print(f"Number of candles between {date1} and {date2}: {diff}")
# Out:
# Number of candles between 2024-01-19 and 2024-01-22: 1

# %% [markdown]
# **get_index**
#
#
# purpose to get the index of the candle for given date.   This is for easy testing and not to be used in prod.

# %%
def get_index(candle_date, df):
    """
    Find the index of the candle with a given date in the DataFrame. Stops processing if the date is not found.

    Parameters:
    - df: DataFrame containing the OHLC data with a 'Date' column.
    - candle_date: The date of the candle to find, as a string in the same format as the DataFrame's 'Date' column.

    Returns:
    - The index of the candle with the given date. Halts execution with an assertion error if the date is not found.
    """
    # Convert the 'Date' column to datetime if it's not already
    df['Date'] = pd.to_datetime(df['Date'])

    # Convert the input date to datetime
    candle_date = pd.to_datetime(candle_date)

    # Find the index of the row that matches the given date
    match = df.index[df['Date'] == candle_date].tolist()

    # Assert that the match list is not empty; if it is, halt execution
    assert match, "Date not found in given OHLC DataFrame. Processing halted."

    # Return the index if found
    return match[0]

# Example usage:
# df = pd.read_csv('path_to_your_file.csv')  # Load your DataFrame here
# candle_index = get_index('1996-01-01', df)
# print(candle_index)

# %%
print(get_index('2023-12-08', df_last_3_months))
print(get_index('1996-01-01', df))
print(type(get_index('2011-08-09', df_last_3_months)))
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 print(get_index('2023-12-08', df_last_3_months))
#       2 print(get_index('1996-01-01', df))
#       3 print(type(get_index('2011-08-09', df_last_3_months)))
#
# Cell In[86], line 22, in get_index(candle_date, df)
#      19 match = df.index[df['Date'] == candle_date].tolist()
#      21 # Assert that the match list is not empty; if it is, halt execution
# ---> 22 assert match, "Date not found in given OHLC DataFrame. Processing halted."
#      24 # Return the index if found
#      25 return match[0]
#
# AssertionError: Date not found in given OHLC DataFrame. Processing halted.

# %%
df_last_3_months.index.min()
# Out:
# 3981

# %%
df.index.max()
# Out:
# 7061

# %% [markdown]
# **get_candle_date**
#
# get candle date for given index

# %%
def get_candle_date(df, index):
    """
    Retrieves the date of the candle for a given index from the DataFrame.

    Parameters:
    - df: DataFrame containing the OHLC data with a 'Date' column.
    - index: The index of the candle whose date you want to retrieve.

    Returns:
    - The date of the candle at the given index, or None if the index is not found.
    """
    try:
        # Access the 'Date' column of the DataFrame at the given index
        candle_date = df.loc[index, 'Date']
        return candle_date
    except KeyError:
        # Return None if the index is not found
        return None

# %% [markdown]
# **Is engulfing next Function**
#
# The overarching idea over here is to find out how many subsequent candles are completely engulfed by a preceding candle.  A candle say A is said to engulfing the subsequent candle say B,  if the high of B is lower than high of A and low of B is higher than low of A.  We need to see how many subsequent candles are being engulfed by a given candle.  Answer might be 0, 1, 2 or n depending on the candle data.   The logic for this function is given below.

# %%
def engulfed_candle_count(candle_index, df):
    """
    Count how many subsequent candles are engulfed by the candle at a given index.

    Parameters:
    - candle_index: The index of the candle to start the check from.
    - df: DataFrame containing the OHLC data.

    Returns:
    - The number of subsequent candles engulfed by the candle at the given index.
    """
    # Initialize the count of engulfed candles
    engulfed_candle_count = 0

    # Find the maximum index in the DataFrame
    max_index = df.index.max()

    # Start a loop to check each subsequent candle
    while True:
        # Ensure we do not exceed the maximum index of the DataFrame
        if candle_index + engulfed_candle_count + 1 > max_index:
            break

        # Get the current and next candle data
        current_candle = df.loc[candle_index]
        next_candle_index = df.index[df.index > candle_index][engulfed_candle_count]  # Get the next available index
        if next_candle_index > max_index:
            break  # Break if the next index is beyond the DataFrame's range

        next_candle = df.loc[next_candle_index]

        # Check if the current candle engulfs the next candle
        if current_candle['High'] >= next_candle['High'] and current_candle['Low'] <= next_candle['Low']:
            # Increase the count as the next candle is engulfed
            engulfed_candle_count += 1
        else:
            # If the next candle is not engulfed, break the loop
            break

    # Return the count of engulfed candles
    return engulfed_candle_count

# %% [markdown]
# **Testing Engulfed_candle_count_function**

# %%
print("No of candles engulfed @ 2024-01-30 are : ", engulfed_candle_count(get_index('2024-01-30',df_last_3_months), df_last_3_months))
print("No of candles engulfed @ 2023-11-16 are : ", engulfed_candle_count(get_index('2023-11-16',df_last_3_months), df_last_3_months))

# checking for second last
print("No of candles engulfed @ 2024-02-07 are : ", engulfed_candle_count(get_index('2024-02-07',df_last_3_months), df_last_3_months))

print("Number of candles @ 2024-01-19 engulfed are : ", engulfed_candle_count(get_index('2024-01-19',df_last_3_months), df_last_3_months))

print("Number of candles @ 2023-12-08 engulfed are : ", engulfed_candle_count(get_index('2023-12-08',df_last_3_months), df_last_3_months))
# Out:
# No of candles engulfed @ 2024-01-30 are :  3
# No of candles engulfed @ 2023-11-16 are :  1
# No of candles engulfed @ 2024-02-07 are :  0
# Number of candles @ 2024-01-19 engulfed are :  1
# Number of candles @ 2023-12-08 engulfed are :  4
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Candle_from_date**

# %%
def candle_from_date(candle_date, df):
    """
    Utility function to get the candle data for a specific date from the DataFrame.

    Parameters:
    - candle_date: The date of the candle to retrieve.
    - df: DataFrame containing OHLC data with a 'Date' column.

    Returns:
    - The row from the DataFrame corresponding to the candle_date.
    """
    return df.loc[df['Date'] == pd.to_datetime(candle_date)].iloc[0]

# %% [markdown]
# **candle_from_extreme_point**

# %%
def candle_from_extreme_point(extreme_point, df):
    """
    Retrieves a candle from the DataFrame based on the date in an extreme point dictionary.

    Parameters:
    - extreme_point: Dictionary with 'mark type', 'date', and 'value' keys.
    - df: DataFrame containing OHLC data with a 'Date' column.

    Returns:
    - The candle data corresponding to the date in the extreme_point dictionary.
    """
    # If extreme_point is None then candle would also be none
    if extreme_point is None:
        return None

    # Extract the date from the extreme_point dictionary
    extreme_point_date = pd.to_datetime(extreme_point['date']).date()

    # Use the candle_from_date utility function to get the candle data
    return candle_from_date(extreme_point_date, df)

# %%
extreme_point = {
    'mark type': 'max',
    'date': pd.Timestamp('2024-01-04 00:00:00'),
    'value': 481.4500122070313
}

# Retrieve the candle corresponding to the extreme point
candle_data = candle_from_extreme_point(extreme_point, df)
print(candle_data)
# Out:
# Date         2024-01-04 00:00:00
# Open                       480.0
# High                  481.450012
# Low                   474.200012
# Close                 476.399994
# Adj Close             469.504456
# Volume                  11786959
# MA200                 439.200001
# MA150                 450.213001
# MA50                  446.436002
# Name: 7037, dtype: object

# %% [markdown]
# # **Extreme Points ZigZag New Approach**
# ---
#
# To implement threshold based approach right at the outset..

# %% [markdown]
# **Step 1: NEXT_EXTREME_HIGH_POINT**

# %%
def next_extreme_high_point(df, start_candle_index=None, input_candle_index=None, percent_threshold=0, move_relative_percent_threshold=0, absolute_threshold=0, pivot_high_candle_index=-1):
    """
    Finds the next extreme high point in stock data, filtering out minor movements below a specified threshold.
    Enhanced with logging for debugging purposes.
    """
    # Initialization with logging
    if start_candle_index is None:
        start_candle_index = df.index.min()
    if input_candle_index is None:
        input_candle_index = start_candle_index
    if pivot_high_candle_index == -1:
        pivot_high_candle_index = input_candle_index

    # print(f"Starting search from index: {start_candle_index}, Input candle index: {input_candle_index}, Pivot high index: {pivot_high_candle_index}")

    pivot_high = df.loc[pivot_high_candle_index, 'High']
    # print(f"Initial pivot high: {pivot_high} at index {pivot_high_candle_index}")

    engulfed_count = engulfed_candle_count(input_candle_index, df)
    next_candle_index = input_candle_index + engulfed_count + 1

    if next_candle_index > df.index.max():
        print("Reached the end of the DataFrame. No more candles to evaluate.")
        return (pivot_high_candle_index, pivot_high, "HIGH")

    next_candle = df.loc[next_candle_index]
    # print(f"Evaluating next candle at index {next_candle_index} with High: {next_candle['High']}")

    if next_candle['High'] > pivot_high:
        pivot_high = next_candle['High']
        pivot_high_candle_index = next_candle_index
        print(f"New pivot high found: {pivot_high} at index {pivot_high_candle_index}")
    else:
        move_in_high = pivot_high - next_candle['High']
        percent_high_move_threshold = pivot_high * (percent_threshold / 100)
        last_move = pivot_high - df.loc[start_candle_index, 'High']
        last_move_based_threshold = last_move * move_relative_percent_threshold /100
        high_move_abs_threshold = max(absolute_threshold, percent_high_move_threshold, last_move_based_threshold)
        # print(f"Move in high: {move_in_high}, Last Move = {last_move}, Last Move based Threshold:{last_move_based_threshold}, Percent high move threshold: {percent_high_move_threshold}, Absolute threshold: {absolute_threshold}")

        if move_in_high >= high_move_abs_threshold:
            print(f"Threshold met. Returning pivot high index: {pivot_high_candle_index}")
            return (pivot_high_candle_index, pivot_high, "HIGH")

    # print("Found new pivot high  OR  Threshold not met. Either ways Continuing search...")
    return next_extreme_high_point(df, start_candle_index=start_candle_index, input_candle_index=next_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold, absolute_threshold=absolute_threshold, pivot_high_candle_index=pivot_high_candle_index)

# %%
# Make sure df_last_3_months['Date'] is in datetime format
df_last_3_months['Date'] = pd.to_datetime(df_last_3_months['Date'])

# Find the index for December 21, 2023
start_date = '2023-11-01'
start_candle_index = get_index(start_date,  df_last_3_months)
next_high_index, next_high_value, extreme_type = next_extreme_high_point(df_last_3_months, start_candle_index=start_candle_index, percent_threshold=3, move_relative_percent_threshold=30, absolute_threshold=0)
print(f"Next extreme {extreme_type} > {next_high_value} is on date:", get_candle_date(df_last_3_months, next_high_index))
# Out:
# New pivot high found: 432.7000122070313 at index 6995
# New pivot high found: 434.3999938964844 at index 6996
# New pivot high found: 436.7999877929688 at index 6997
# New pivot high found: 437.5 at index 6999
# New pivot high found: 438.0 at index 7000
# New pivot high found: 438.3999938964844 at index 7002
# New pivot high found: 442.5 at index 7003
# New pivot high found: 444.5 at index 7004
# New pivot high found: 450.9500122070313 at index 7014
# New pivot high found: 456.3999938964844 at index 7015
# New pivot high found: 457.7999877929688 at index 7016
# New pivot high found: 464.5 at index 7017
# New pivot high found: 464.7999877929688 at index 7018
# New pivot high found: 467.8999938964844 at index 7033
# New pivot high found: 469.9500122070313 at index 7034
# New pivot high found: 471.3500061035156 at index 7035
# New pivot high found: 480.7000122070313 at index 7036
# New pivot high found: 481.4500122070313 at index 7037
# Threshold met. Returning pivot high index: 7037
# Next extreme HIGH > 481.4500122070313 is on date: 2024-01-04 00:00:00
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1622473385.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Step 2: NEXT_EXTREME_LOW_POINT**

# %%
def next_extreme_low_point(df, start_candle_index=None, input_candle_index=None, percent_threshold=0, move_relative_percent_threshold=0, absolute_threshold=0, pivot_low_candle_index=-1):
    """
    Identifies the next extreme low point in a dataset of stock prices, filtering out minor movements.
    Debugging statements are active for detailed insights during execution.
    """
    if start_candle_index is None:
        start_candle_index = df.index.min()

    if input_candle_index is None:
        input_candle_index = start_candle_index

    if pivot_low_candle_index == -1:
        pivot_low_candle_index = input_candle_index

    pivot_low = df.loc[pivot_low_candle_index, 'Low']
    # print(f"Starting search from index: {start_candle_index}, Input candle index: {input_candle_index}, Pivot low index: {pivot_low_candle_index}, Initial pivot low: {pivot_low}")

    engulfed_count = engulfed_candle_count(input_candle_index, df)
    next_candle_index = input_candle_index + engulfed_count + 1

    if next_candle_index > df.index.max():
        # print(f"Reached the end of the DataFrame. No more candles to evaluate.End index of df is {df.index.max()}")
        # print("pivot_low_candle_index is  ", pivot_low_candle_index)
        return (pivot_low_candle_index, pivot_low, "LOW")

    next_candle = df.loc[next_candle_index]
    # print(f"Evaluating next candle at index {next_candle_index} with Low: {next_candle['Low']}")

    if next_candle_index > df.index.max():
        print("Reached the end of the DataFrame. No more candles to evaluate.")
        return (pivot_low_candle_index, pivot_low, "LOW")

    if next_candle['Low'] < pivot_low:
        pivot_low = next_candle['Low']
        pivot_low_candle_index = next_candle_index
        print(f"New pivot low found: {pivot_low} at index {pivot_low_candle_index}")
    else:
        move_in_low = next_candle['Low'] - pivot_low
        percent_low_move_threshold = pivot_low * (percent_threshold / 100)
        last_move = df.loc[start_candle_index, 'Low'] - pivot_low
        last_move_based_threshold = last_move * move_relative_percent_threshold /100
        low_move_abs_threshold = max(absolute_threshold, percent_low_move_threshold, last_move_based_threshold)
        # print(f"Move in low: {move_in_low}, Last Move = {last_move}, Last Move based Threshold:{last_move_based_threshold}, Percent low move threshold: {percent_low_move_threshold}, Absolute threshold: {low_move_abs_threshold}")

        if move_in_low >= low_move_abs_threshold:  # Check for significant move away from the low
            print(f"Threshold met. Returning pivot low index: {pivot_low_candle_index}")
            return (pivot_low_candle_index, pivot_low, "LOW")

    # print("Found new pivot low  OR  Threshold not met. Either ways Continuing search...")
    return next_extreme_low_point(df, start_candle_index=start_candle_index, input_candle_index=next_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold, absolute_threshold=absolute_threshold, pivot_low_candle_index=pivot_low_candle_index)

# %%
# Make sure df_last_3_months['Date'] is in datetime format
df_last_3_months['Date'] = pd.to_datetime(df_last_3_months['Date'])

# Find the index for December 21, 2023
start_date = '2023-01-04'
start_candle_index = get_index(start_date,  df_last_3_months)

next_low_index, next_low_point, extreme_type = next_extreme_low_point(df_last_3_months, start_candle_index=start_candle_index, percent_threshold=2, move_relative_percent_threshold=20, absolute_threshold=0)
print(f"Next extreme {extreme_type} point > {next_low_point} is at date:", get_candle_date(df_last_3_months, next_low_index))
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\445644996.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Threshold met. Returning pivot low index: 6791
# Next extreme LOW point > 326.0 is at date: 2023-01-04 00:00:00

# %% [markdown]
# **Step 3: NEXT_EXTREME_CANDLE**

# %%
def next_extreme_candle(df, start_candle_index, input_candle_index=None, percent_threshold=0, move_relative_percent_threshold=0, absolute_threshold=0, pivot_high_candle_index=-1, pivot_low_candle_index=-1):
    """
    Identifies the next extreme point (high or low) in stock price data, filtering out minor fluctuations.

    Parameters:
    - df: DataFrame containing stock data.
    - start_candle_index: Index to start the search from.
    - input_candle_index: Current candle being considered. If None, set to start_candle_index.
    - percent_threshold: Minimum percentage movement required to consider a point significant.
    - absolute_threshold: Minimum absolute movement required to consider a point significant.
    - pivot_high_candle_index: Index of the current pivot high candle. Initialized to start_candle_index if -1.
    - pivot_low_candle_index: Index of the current pivot low candle. Initialized to start_candle_index if -1.

    Returns:
    - Index of the next extreme point that meets threshold criteria.
    """
    if start_candle_index is None:
        start_candle_index = df.index.min()

    if input_candle_index is None:
        input_candle_index = start_candle_index

    if pivot_high_candle_index == -1 and pivot_low_candle_index == -1:
        pivot_high_candle_index = pivot_low_candle_index = input_candle_index

    pivot_high = df.loc[pivot_high_candle_index, 'High']
    pivot_low = df.loc[pivot_low_candle_index, 'Low']

    engulfed_count = engulfed_candle_count(input_candle_index, df)
    next_candle_index = input_candle_index + engulfed_count + 1

    if next_candle_index >= df.index.max():
        # print("Reached the end of the DataFrame. No further candles to evaluate. Giving most recent relevant point as default")
        if pivot_high_candle_index > pivot_low_candle_index:
              return (pivot_high_candle_index, pivot_high, "HIGH")
        elif pivot_high_candle_index < pivot_low_candle_index:
              return (pivot_low_candle_index, pivot_low, "LOW")
        else:
              return (pivot_high_candle_index, pivot_high, "HIGH")

    # print(f"next_candle_index is {next_candle_index}")
    next_candle = df.loc[next_candle_index]

    # Adjust pivot points if the next candle sets a new extreme
    if next_candle['Low'] < pivot_low:
        pivot_low = next_candle['Low']
        pivot_low_candle_index = next_candle_index
        # print(f"New pivot low found: {pivot_low} at index {pivot_low_candle_index}")
    else:
        move_in_low = next_candle['Low'] - pivot_low
        percent_low_move_threshold = pivot_low * (percent_threshold / 100)
        low_move_abs_threshold = max(absolute_threshold, percent_low_move_threshold)
        # Determine if the next extreme candle is a low or high point
        if move_in_low >= low_move_abs_threshold:
            if pivot_low_candle_index > start_candle_index:
                # print(f"Pivot point is the next extreme low point and pivot_low_candle_index is : {pivot_low_candle_index}")
                return (pivot_low_candle_index, pivot_low, "LOW")
            else:
                # print(f"Significant movement upwards from start_index identified at the candle index : {next_candle_index}..  exploring the high point now...")
                return next_extreme_high_point(df, start_candle_index=start_candle_index, input_candle_index=next_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold, absolute_threshold=absolute_threshold, pivot_high_candle_index=-1)

    if next_candle['High'] > pivot_high:
        pivot_high = next_candle['High']
        pivot_high_candle_index = next_candle_index
        # print(f"New pivot high found: {pivot_high} at index {pivot_high_candle_index}")
    else:
        move_in_high = pivot_high - next_candle['High']
        percent_high_move_threshold = pivot_high * (percent_threshold / 100)
        high_move_abs_threshold = max(absolute_threshold, percent_high_move_threshold)
        if move_in_high >= high_move_abs_threshold:
            if pivot_high_candle_index > start_candle_index:
                # print(f"New pivot high found: {pivot_high} at index {pivot_high_candle_index}")
                return (pivot_high_candle_index, pivot_high, "HIGH")
            else:
                # print(f"Significant movement downward from start_index identified at the candle index : {next_candle_index}..  exploring the low point now..")
                return next_extreme_low_point(df, start_candle_index=start_candle_index, input_candle_index=next_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold, absolute_threshold=absolute_threshold, pivot_low_candle_index=-1)

    # Continue searching if neither threshold is met
    # print("No significant move detected. Continuing search...")
    return next_extreme_candle(df, start_candle_index, next_candle_index, percent_threshold, move_relative_percent_threshold, absolute_threshold, pivot_high_candle_index, pivot_low_candle_index)

# %%
# Make sure df_last_3_months['Date'] is in datetime format
df_last_3_months['Date'] = pd.to_datetime(df_last_3_months['Date'])

# Find the index for December 21, 2023
start_date = '2024-02-06'
start_candle_index = get_index(start_date,  df_last_3_months)

# Assuming next_extreme_high_point and get_index functions are already defined
next_extreme_index, next_extreme, extreme_type = next_extreme_candle(df_last_3_months, start_candle_index=start_candle_index, percent_threshold=0, move_relative_percent_threshold=0, absolute_threshold=0)
print(f"Next extreme {extreme_type} point > {next_extreme} is at date:", get_candle_date(df_last_3_months, next_extreme_index))
# Out:
# Next extreme HIGH point > 440.8999938964844 is at date: 2024-02-06 00:00:00
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1158667665.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Step 3: ZigZag**

# %%
def zig_zag(df, percent_threshold=0,  move_relative_percent_threshold=0, absolute_threshold=0):
    """
    Generates a Zig Zag pattern by identifying a series of high and low extreme points
    in a given OHLC DataFrame.

    Parameters:
    - df: DataFrame containing OHLC data.
    - percent_threshold: The percentage movement threshold for considering an extreme point.
    - absolute_threshold: The absolute movement threshold for considering an extreme point.

    Returns:
    - A list of tuples, each containing the index of the extreme point and its type ("MAX" or "MIN").
    """

    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])

    # Initialize the list to store the extreme points
    extreme_points = []

    # Start with the first candle in the DataFrame
    start_candle_index = df.index.min()
    current_type = None  # Keep track of the current extreme type to alternate between high and low

    while True:
        # Use next_extreme_candle to find the next extreme point from the current starting point
        next_point_index, next_extreme_value, extreme_type = next_extreme_candle(df, start_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold,  absolute_threshold=absolute_threshold)

        # Debugging statement to show the progress
        # print(f"Found extreme point at index {next_point_index} of type {extreme_type}")

        # Check if the next_point_index is None or if we've encountered a repeat
        if next_point_index == start_candle_index :
            # print("Encountered a repeat index")
            # Repeat index happens because that point itself is the extreme point hence it points at itsel
            if next_point_index is None:
                # print("Reached the End of dataframe")
                2==2
            break

        # Add the found extreme point to the list
        extreme_points.append((next_point_index, next_extreme_value, extreme_type))

        # Update start_candle_index for the next iteration
        start_candle_index = next_point_index

        # Check if we've reached the end of the DataFrame
        if start_candle_index == df.index.max():
            # print("Reached the end of DataFrame.")
            break

    return extreme_points

# %%
# Assuming the DataFrame 'df_last_3_months' is already loaded and prepared
extreme_points = zig_zag(df_last_3_months, percent_threshold=5, move_relative_percent_threshold=0, absolute_threshold=0)

# for index, value, point_type in extreme_points:
#     print(f"Extreme point at index {index}, type: {point_type}, value: {value}, Date: {df_last_3_months.loc[index, 'Date']}")
# Out:
# New pivot high found: 137.6666717529297 at index 3996
# Threshold met. Returning pivot high index: 3996
# New pivot low found: 123.33333587646484 at index 4012
# Threshold met. Returning pivot low index: 4012
# New pivot high found: 136.3333282470703 at index 4023
# New pivot high found: 136.93333435058594 at index 4024
# New pivot high found: 137.26666259765625 at index 4025
# New pivot high found: 137.46665954589844 at index 4026
# New pivot high found: 138.5 at index 4028
# New pivot high found: 138.6666717529297 at index 4031
# New pivot high found: 142.0 at index 4032
# New pivot high found: 144.13333129882812 at index 4033
# Threshold met. Returning pivot high index: 4033
# New pivot low found: 130.13333129882812 at index 4048
# New pivot low found: 126.1999969482422 at index 4049
# Threshold met. Returning pivot low index: 4049
# New pivot high found: 138.0 at index 4056
# New pivot high found: 138.39999389648438 at index 4057
# New pivot high found: 138.6666717529297 at index 4058
# New pivot high found: 139.8000030517578 at index 4086
# New pivot high found: 140.13333129882812 at index 4087
# New pivot high found: 140.46665954589844 at index 4088
# New pivot high found: 140.6666717529297 at index 4089
# New pivot high found: 140.86666870117188 at index 4090
# New pivot high found: 141.93333435058594 at index 4114
# New pivot high found: 142.3333282470703 at index 4115
# New pivot high found: 150.0 at index 4127
# New pivot high found: 151.13333129882812 at index 4131
# New pivot high found: 151.5 at index 4134
# New pivot high found: 151.93333435058594 at index 4135
# New pivot high found: 152.23333740234375 at index 4138
# New pivot high found: 152.60000610351562 at index 4140
# New pivot high found: 153.3333282470703 at index 4142
# New pivot high found: 153.39999389648438 at index 4143
# New pivot high found: 156.6666717529297 at index 4144
# New pivot high found: 160.56666564941406 at index 4145
# New pivot high found: 161.3333282470703 at index 4146
# New pivot high found: 165.0 at index 4147
# New pivot high found: 165.36666870117188 at index 4148
# New pivot high found: 166.60000610351562 at index 4154
# New pivot high found: 168.56666564941406 at index 4155
# Threshold met. Returning pivot high index: 4155
# New pivot low found: 149.23333740234375 at index 4161
# Threshold met. Returning pivot low index: 4161
# Threshold met. Returning pivot high index: 4163
# New pivot low found: 150.0 at index 4181
# Threshold met. Returning pivot low index: 4181
# New pivot high found: 165.76666259765625 at index 4188
# New pivot high found: 165.86666870117188 at index 4189
# New pivot high found: 166.6666717529297 at index 4190
# New pivot high found: 168.0 at index 4193
# New pivot high found: 168.6666717529297 at index 4194
# New pivot high found: 169.26666259765625 at index 4195
# New pivot high found: 173.3333282470703 at index 4199
# New pivot high found: 173.60000610351562 at index 4200
# New pivot high found: 173.86666870117188 at index 4221
# New pivot high found: 174.6666717529297 at index 4223
# New pivot high found: 175.6999969482422 at index 4227
# New pivot high found: 177.89999389648438 at index 4228
# New pivot high found: 179.3333282470703 at index 4229
# New pivot high found: 179.60000610351562 at index 4231
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2338709250.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# New pivot high found: 471.3500061035156 at index 7035
# New pivot high found: 480.7000122070313 at index 7036
# New pivot high found: 481.4500122070313 at index 7037
# Threshold met. Returning pivot high index: 7037
# New pivot low found: 437.3999938964844 at index 7054
# New pivot low found: 436.5499877929688 at index 7058
# New pivot low found: 429.5 at index 7059
# New pivot low found: 408.6000061035156 at index 7061

# %%
extreme_points2 = zig_zag(df_last_3_months, percent_threshold=0, move_relative_percent_threshold=0, absolute_threshold=0)
# Out:
# Threshold met. Returning pivot high index: 3982
# New pivot low found: 130.3333282470703 at index 3984
# Threshold met. Returning pivot low index: 3984
# New pivot high found: 136.6666717529297 at index 3986
# New pivot high found: 137.3333282470703 at index 3987
# Threshold met. Returning pivot high index: 3987
# New pivot low found: 131.03334045410156 at index 3989
# Threshold met. Returning pivot low index: 3989
# New pivot high found: 136.1999969482422 at index 3991
# Threshold met. Returning pivot high index: 3991
# Threshold met. Returning pivot low index: 3993
# New pivot high found: 137.6666717529297 at index 3996
# Threshold met. Returning pivot high index: 3996
# New pivot low found: 129.8000030517578 at index 4002
# Threshold met. Returning pivot low index: 4002
# New pivot high found: 133.3333282470703 at index 4004
# New pivot high found: 134.56666564941406 at index 4005
# Threshold met. Returning pivot high index: 4005
# Threshold met. Returning pivot low index: 4007
# New pivot high found: 133.10000610351562 at index 4009
# Threshold met. Returning pivot high index: 4009
# New pivot low found: 126.03333282470705 at index 4011
# New pivot low found: 123.33333587646484 at index 4012
# Threshold met. Returning pivot low index: 4012
# New pivot high found: 131.6666717529297 at index 4014
# New pivot high found: 135.3000030517578 at index 4015
# Threshold met. Returning pivot high index: 4015
# New pivot low found: 125.73332977294922 at index 4018
# Threshold met. Returning pivot low index: 4018
# New pivot high found: 133.5 at index 4020
# New pivot high found: 134.26666259765625 at index 4021
# New pivot high found: 134.93333435058594 at index 4022
# New pivot high found: 136.3333282470703 at index 4023
# New pivot high found: 136.93333435058594 at index 4024
# New pivot high found: 137.26666259765625 at index 4025
# New pivot high found: 137.46665954589844 at index 4026
# Threshold met. Returning pivot high index: 4026
# Threshold met. Returning pivot low index: 4027
# Threshold met. Returning pivot high index: 4028
# Threshold met. Returning pivot low index: 4030
# New pivot high found: 142.0 at index 4032
# New pivot high found: 144.13333129882812 at index 4033
# Threshold met. Returning pivot high index: 4033
# New pivot low found: 138.46665954589844 at index 4035
# New pivot low found: 138.3333282470703 at index 4036
# Threshold met. Returning pivot low index: 4036
# New pivot high found: 141.39999389648438 at index 4039
# New pivot high found: 143.0 at index 4040
# New pivot high found: 143.3333282470703 at index 4041
# New pivot high found: 143.53334045410156 at index 4042
# Threshold met. Returning pivot high index: 4042
# New pivot low found: 138.8333282470703 at index 4044
# New pivot low found: 137.39999389648438 at index 4045
# New pivot low found: 133.39999389648438 at index 4046
# New pivot low found: 132.06666564941406 at index 4047
# New pivot low found: 130.13333129882812 at index 4048
# New pivot low found: 126.1999969482422 at index 4049
# Threshold met. Returning pivot low index: 4049
# New pivot high found: 134.3333282470703 at index 4054
# New pivot high found: 137.26666259765625 at index 4055
# New pivot high found: 138.0 at index 4056
# New pivot high found: 138.39999389648438 at index 4057
# New pivot high found: 138.6666717529297 at index 4058
# Threshold met. Returning pivot high index: 4058
# New pivot low found: 129.8000030517578 at index 4060
# Threshold met. Returning pivot low index: 4060
# New pivot high found: 134.3333282470703 at index 4063
# New pivot high found: 135.56666564941406 at index 4065
# Threshold met. Returning pivot high index: 4065
# Threshold met. Returning pivot low index: 4066
# New pivot high found: 135.3000030517578 at index 4068
# New pivot high found: 136.0 at index 4069
# New pivot high found: 136.6666717529297 at index 4070
# New pivot high found: 137.23333740234375 at index 4071
# New pivot high found: 137.3333282470703 at index 4072
# Threshold met. Returning pivot high index: 4072
# New pivot low found: 133.3333282470703 at index 4074
# New pivot low found: 131.93333435058594 at index 4076
# New pivot low found: 131.73333740234375 at index 4079
# Threshold met. Returning pivot low index: 4079
# New pivot high found: 137.1666717529297 at index 4082
# New pivot high found: 138.46665954589844 at index 4085
# New pivot high found: 139.8000030517578 at index 4086
# New pivot high found: 140.13333129882812 at index 4087
# New pivot high found: 140.46665954589844 at index 4088
# New pivot high found: 140.6666717529297 at index 4089
# New pivot high found: 140.86666870117188 at index 4090
# Threshold met. Returning pivot high index: 4090
# Threshold met. Returning pivot low index: 4091
# New pivot high found: 138.3333282470703 at index 4094
# Threshold met. Returning pivot high index: 4094
# Threshold met. Returning pivot low index: 4095
# Threshold met. Returning pivot high index: 4096
# New pivot low found: 132.26666259765625 at index 4098
# New pivot low found: 131.3333282470703 at index 4099
# Threshold met. Returning pivot low index: 4099
# New pivot high found: 137.26666259765625 at index 4101
# New pivot high found: 138.3000030517578 at index 4102
# New pivot high found: 139.13333129882812 at index 4110
# New pivot high found: 139.60000610351562 at index 4111
# New pivot high found: 140.06666564941406 at index 4112
# New pivot high found: 140.63333129882812 at index 4113
# New pivot high found: 141.93333435058594 at index 4114
# New pivot high found: 142.3333282470703 at index 4115
# Threshold met. Returning pivot high index: 4115
# New pivot low found: 136.53334045410156 at index 4117
# New pivot low found: 135.60000610351562 at index 4118
# Threshold met. Returning pivot low index: 4118
# New pivot high found: 141.13333129882812 at index 4120
# New pivot high found: 141.8333282470703 at index 4122
# Threshold met. Returning pivot high index: 4122
# Threshold met. Returning pivot low index: 4123
# Threshold met. Returning pivot high index: 4125
# Threshold met. Returning pivot low index: 4126
# New pivot high found: 151.13333129882812 at index 4131
# New pivot high found: 151.5 at index 4134
# New pivot high found: 151.93333435058594 at index 4135
# Threshold met. Returning pivot high index: 4135
# Threshold met. Returning pivot low index: 4136
# New pivot high found: 152.23333740234375 at index 4138
# New pivot high found: 152.60000610351562 at index 4140
# Threshold met. Returning pivot high index: 4140
# Threshold met. Returning pivot low index: 4141
# New pivot high found: 153.39999389648438 at index 4143
# New pivot high found: 156.6666717529297 at index 4144
# New pivot high found: 160.56666564941406 at index 4145
# New pivot high found: 161.3333282470703 at index 4146
# New pivot high found: 165.0 at index 4147
# New pivot high found: 165.36666870117188 at index 4148
# Threshold met. Returning pivot high index: 4148
# Threshold met. Returning pivot low index: 4149
# New pivot high found: 165.13333129882812 at index 4151
# Threshold met. Returning pivot high index: 4151
# Threshold met. Returning pivot low index: 4152
# New pivot high found: 166.60000610351562 at index 4154
# New pivot high found: 168.56666564941406 at index 4155
# Threshold met. Returning pivot high index: 4155
# New pivot low found: 160.6666717529297 at index 4158
# New pivot low found: 158.23333740234375 at index 4159
# New pivot low found: 155.56666564941406 at index 4160
# New pivot low found: 149.23333740234375 at index 4161
# Threshold met. Returning pivot low index: 4161
# Threshold met. Returning pivot high index: 4163
# New pivot low found: 153.39999389648438 at index 4166
# New pivot low found: 150.93333435058594 at index 4167
# Threshold met. Returning pivot low index: 4167
# New pivot high found: 160.6666717529297 at index 4169
# Threshold met. Returning pivot high index: 4169
# Threshold met. Returning pivot low index: 4178
# Threshold met. Returning pivot high index: 4179
# Threshold met. Returning pivot low index: 4181
# New pivot high found: 159.53334045410156 at index 4183
# New pivot high found: 160.86666870117188 at index 4184
# New pivot high found: 162.8333282470703 at index 4186
# New pivot high found: 163.26666259765625 at index 4187
# New pivot high found: 165.76666259765625 at index 4188
# New pivot high found: 165.86666870117188 at index 4189
# New pivot high found: 166.6666717529297 at index 4190
# New pivot high found: 168.0 at index 4193
# New pivot high found: 168.6666717529297 at index 4194
# New pivot high found: 169.26666259765625 at index 4195
# Threshold met. Returning pivot high index: 4195
# Threshold met. Returning pivot low index: 4196
# New pivot high found: 173.3333282470703 at index 4199
# New pivot high found: 173.60000610351562 at index 4200
# Threshold met. Returning pivot high index: 4200
# New pivot low found: 163.0 at index 4202
# Threshold met. Returning pivot low index: 4202
# New pivot high found: 169.0 at index 4204
# New pivot high found: 169.93333435058594 at index 4205
# New pivot high found: 172.8000030517578 at index 4206
# Threshold met. Returning pivot high index: 4206
# Threshold met. Returning pivot low index: 4215
# New pivot high found: 170.1999969482422 at index 4217
# New pivot high found: 171.3333282470703 at index 4218
# New pivot high found: 172.53334045410156 at index 4220
# New pivot high found: 173.86666870117188 at index 4221
# New pivot high found: 174.6666717529297 at index 4223
# Threshold met. Returning pivot high index: 4223
# New pivot low found: 171.6666717529297 at index 4225
# New pivot low found: 171.39999389648438 at index 4226
# Threshold met. Returning pivot low index: 4226
# New pivot high found: 177.89999389648438 at index 4228
# New pivot high found: 179.3333282470703 at index 4229
# Threshold met. Returning pivot high index: 4229
# Threshold met. Returning pivot low index: 4230
# Threshold met. Returning pivot high index: 4231
# Threshold met. Returning pivot low index: 4232
# New pivot high found: 182.1666717529297 at index 4241
# Threshold met. Returning pivot high index: 4241
# Threshold met. Returning pivot low index: 4244
# Threshold met. Returning pivot high index: 4245
# Threshold met. Returning pivot low index: 4246
# New pivot high found: 180.0 at index 4250
# New pivot high found: 180.1999969482422 at index 4251
# New pivot high found: 181.86666870117188 at index 4252
# Threshold met. Returning pivot high index: 4252
# Threshold met. Returning pivot low index: 4253
# New pivot high found: 183.3333282470703 at index 4262
# Threshold met. Returning pivot high index: 4262
# Threshold met. Returning pivot low index: 4522
# Threshold met. Returning pivot high index: 4523
# New pivot low found: 217.5333404541016 at index 4525
# New pivot low found: 215.3333282470703 at index 4526
# Threshold met. Returning pivot low index: 4526
# New pivot high found: 224.3333282470703 at index 4528
# Threshold met. Returning pivot high index: 4528
# New pivot low found: 212.0666656494141 at index 4530
# New pivot low found: 211.46665954589844 at index 4531
# New pivot low found: 210.0 at index 4532
# New pivot low found: 208.73333740234372 at index 4534
# New pivot low found: 208.0 at index 4537
# Threshold met. Returning pivot low index: 4537
# New pivot high found: 218.43333435058597 at index 4539
# Threshold met. Returning pivot high index: 4539
# New pivot low found: 207.3999938964844 at index 4541
# New pivot low found: 205.1666717529297 at index 4542
# Threshold met. Returning pivot low index: 4542
# Threshold met. Returning pivot high index: 4543
# Threshold met. Returning pivot low index: 4544
# New pivot high found: 214.0 at index 4547
# New pivot high found: 215.8000030517578 at index 4548
# Threshold met. Returning pivot high index: 4548
# New pivot low found: 207.8999938964844 at index 4550
# New pivot low found: 205.0333404541016 at index 4551
# Threshold met. Returning pivot low index: 4551
# New pivot high found: 214.5 at index 4555
# New pivot high found: 214.6666717529297 at index 4556
# Threshold met. Returning pivot high index: 4556
# New pivot low found: 207.13333129882807 at index 4558
# Threshold met. Returning pivot low index: 4558
# New pivot high found: 211.76666259765625 at index 4560
# Threshold met. Returning pivot high index: 4560
# New pivot low found: 206.8999938964844 at index 4562
# Threshold met. Returning pivot low index: 4562
# New pivot high found: 213.3333282470703 at index 4564
# New pivot high found: 214.26666259765625 at index 4565
# New pivot high found: 215.76666259765625 at index 4566
# New pivot high found: 216.0 at index 4567
# New pivot high found: 216.6666717529297 at index 4570
# Threshold met. Returning pivot high index: 4570
# Threshold met. Returning pivot low index: 4571
# New pivot high found: 211.6000061035156 at index 4573
# New pivot high found: 212.0 at index 4574
# Threshold met. Returning pivot high index: 4574
# Threshold met. Returning pivot low index: 4575
# New pivot high found: 217.5333404541016 at index 4577
# New pivot high found: 220.0 at index 4578
# Threshold met. Returning pivot high index: 4578
# Threshold met. Returning pivot low index: 4579
# Threshold met. Returning pivot high index: 4580
# Threshold met. Returning pivot low index: 4581
# New pivot high found: 221.5666656494141 at index 4583
# Threshold met. Returning pivot high index: 4583
# Threshold met. Returning pivot low index: 4584
# New pivot high found: 220.26666259765625 at index 4586
# Threshold met. Returning pivot high index: 4586
# Threshold met. Returning pivot low index: 4587
# New pivot high found: 219.0 at index 4589
# Threshold met. Returning pivot high index: 4589
# New pivot low found: 210.6000061035156 at index 4593
# Threshold met. Returning pivot low index: 4593
# Threshold met. Returning pivot high index: 4596
# New pivot low found: 210.1666717529297 at index 4600
# New pivot low found: 209.8000030517578 at index 4601
# Threshold met. Returning pivot low index: 4601
# Threshold met. Returning pivot high index: 4602
# New pivot low found: 210.73333740234372 at index 4604
# New pivot low found: 207.6000061035156 at index 4605
# Threshold met. Returning pivot low index: 4605
# New pivot high found: 213.6666717529297 at index 4607
# New pivot high found: 214.93333435058597 at index 4608
# Threshold met. Returning pivot high index: 4720
# Threshold met. Returning pivot low index: 4721
# New pivot high found: 241.23333740234372 at index 4723
# Threshold met. Returning pivot high index: 4723
# New pivot low found: 229.26666259765625 at index 4726
# New pivot low found: 227.6999969482422 at index 4728
# Threshold met. Returning pivot low index: 4728
# New pivot high found: 235.86666870117188 at index 4730
# New pivot high found: 236.6000061035156 at index 4731
# New pivot high found: 238.0 at index 4732
# New pivot high found: 238.6666717529297 at index 4733
# Threshold met. Returning pivot high index: 4733
# New pivot low found: 232.1999969482422 at index 4735
# Threshold met. Returning pivot low index: 4735
# Threshold met. Returning pivot high index: 4739
# New pivot low found: 233.0 at index 4741
# Threshold met. Returning pivot low index: 4741
# Threshold met. Returning pivot high index: 4742
# Threshold met. Returning pivot low index: 4743
# New pivot high found: 239.0 at index 4745
# New pivot high found: 239.3333282470703 at index 4746
# New pivot high found: 240.5333404541016 at index 4747
# New pivot high found: 248.0 at index 4748
# New pivot high found: 249.93333435058597 at index 4749
# New pivot high found: 252.6666717529297 at index 4750
# New pivot high found: 253.26666259765625 at index 4751
# Threshold met. Returning pivot high index: 4751
# New pivot low found: 243.0 at index 4753
# New pivot low found: 242.0 at index 4754
# New pivot low found: 238.73333740234372 at index 4756
# Threshold met. Returning pivot low index: 4756
# New pivot high found: 245.5333404541016 at index 4758
# Threshold met. Returning pivot high index: 4758
# New pivot low found: 231.46665954589844 at index 4760
# New pivot low found: 229.0 at index 4761
# New pivot low found: 228.96665954589844 at index 4763
# Threshold met. Returning pivot low index: 4763
# Threshold met. Returning pivot high index: 4764
# New pivot low found: 232.0 at index 4766
# Threshold met. Returning pivot low index: 4766
# Threshold met. Returning pivot high index: 4767
# Threshold met. Returning pivot low index: 4768
# New pivot high found: 236.6666717529297 at index 4770
# New pivot high found: 238.5 at index 4771
# New pivot high found: 240.0 at index 4772
# New pivot high found: 240.3333282470703 at index 4775
# New pivot high found: 248.3333282470703 at index 4776
# New pivot high found: 251.5 at index 4783
# New pivot high found: 252.5333404541016 at index 4787
# New pivot high found: 256.0 at index 4794
# New pivot high found: 261.3333435058594 at index 4795
# New pivot high found: 266.4666748046875 at index 4796
# New pivot high found: 266.6666564941406 at index 4797
# Threshold met. Returning pivot high index: 4797
# Threshold met. Returning pivot low index: 4798
# New pivot high found: 266.8666687011719 at index 4800
# Threshold met. Returning pivot high index: 4800
# New pivot low found: 251.93333435058597 at index 4802
# New pivot low found: 244.3999938964844 at index 4803
# New pivot low found: 243.3333282470703 at index 4804
# New pivot low found: 239.3333282470703 at index 4816
# New pivot low found: 235.3333282470703 at index 4817
# Threshold met. Returning pivot low index: 4817
# Threshold met. Returning pivot high index: 4819
# Threshold met. Returning pivot low index: 4822
# New pivot high found: 241.3000030517578 at index 4824
# New pivot high found: 247.8999938964844 at index 4826
# New pivot high found: 248.63333129882807 at index 4827
# Threshold met. Returning pivot high index: 4827
# New pivot low found: 232.5333404541016 at index 4829
# Threshold met. Returning pivot low index: 4829
# New pivot high found: 242.3000030517578 at index 4831
# New pivot high found: 248.0 at index 4832
# Threshold met. Returning pivot high index: 4832
# Threshold met. Returning pivot low index: 4834
# New pivot high found: 248.0666656494141 at index 4837
# New pivot high found: 249.6000061035156 at index 4838
# Threshold met. Returning pivot high index: 4838
# Threshold met. Returning pivot low index: 4842
# New pivot high found: 260.6666564941406 at index 4844
# New pivot high found: 268.0 at index 4845
# Threshold met. Returning pivot high index: 4845
# Threshold met. Returning pivot low index: 4846
# New pivot high found: 265.8666687011719 at index 4848
# Threshold met. Returning pivot high index: 4848
# Threshold met. Returning pivot low index: 4849
# New pivot high found: 267.6000061035156 at index 4851
# Threshold met. Returning pivot high index: 4851
# New pivot low found: 228.0 at index 4853
# New pivot low found: 226.0 at index 4854
# Threshold met. Returning pivot low index: 4854
# Threshold met. Returning pivot high index: 4855
# New pivot low found: 224.8333282470703 at index 4857
# New pivot low found: 223.3999938964844 at index 4858
# Threshold met. Returning pivot low index: 4858
# New pivot high found: 233.3333282470703 at index 4861
# Threshold met. Returning pivot high index: 4861
# New pivot low found: 221.0 at index 4865
# New pivot low found: 217.6000061035156 at index 4866
# New pivot low found: 216.6666717529297 at index 4867
# New pivot low found: 213.73333740234372 at index 4870
# New pivot low found: 210.0666656494141 at index 4871
# Threshold met. Returning pivot low index: 4871
# New pivot high found: 222.0 at index 4874
# New pivot high found: 227.76666259765625 at index 4875
# New pivot high found: 228.6666717529297 at index 4876
# New pivot high found: 231.3000030517578 at index 4877
# New pivot high found: 232.63333129882807 at index 4878
# Threshold met. Returning pivot high index: 4878
# Threshold met. Returning pivot low index: 4879
# New pivot high found: 239.0666656494141 at index 4881
# Threshold met. Returning pivot high index: 4881
# New pivot low found: 227.0666656494141 at index 4884
# New pivot low found: 225.6999969482422 at index 4886
# New pivot low found: 225.5333404541016 at index 4887
# Threshold met. Returning pivot low index: 4887
# New pivot high found: 234.5333404541016 at index 4889
# Threshold met. Returning pivot high index: 4889
# New pivot low found: 218.1999969482422 at index 4891
# New pivot low found: 214.13333129882807 at index 4892
# New pivot low found: 213.3999938964844 at index 4893
# New pivot low found: 210.8000030517578 at index 4895
# New pivot low found: 210.3999938964844 at index 4896
# Threshold met. Returning pivot low index: 4896
# New pivot high found: 220.5 at index 4898
# Threshold met. Returning pivot high index: 4898
# New pivot low found: 214.0 at index 4900
# Threshold met. Returning pivot low index: 4900
# New pivot high found: 223.93333435058597 at index 4904
# Threshold met. Returning pivot high index: 4904
# New pivot low found: 217.3333282470703 at index 4906
# New pivot low found: 216.96665954589844 at index 4907
# New pivot low found: 210.93333435058597 at index 4908
# New pivot low found: 208.5 at index 4909
# Threshold met. Returning pivot low index: 4909
# New pivot high found: 214.96665954589844 at index 4911
# New pivot high found: 219.96665954589844 at index 4912
# New pivot high found: 222.5 at index 4913
# Threshold met. Returning pivot high index: 4913
# New pivot low found: 200.3999938964844 at index 4915
# New pivot low found: 198.8000030517578 at index 4916
# New pivot low found: 196.6666717529297 at index 4917
# Threshold met. Returning pivot low index: 4917
# Threshold met. Returning pivot high index: 4918
# New pivot low found: 199.0666656494141 at index 4920
# New pivot low found: 196.8000030517578 at index 4921
# New pivot low found: 196.6666717529297 at index 4922
# New pivot low found: 196.0 at index 4923
# Threshold met. Returning pivot low index: 4923
# New pivot high found: 202.93333435058597 at index 4926
# New pivot high found: 203.63333129882807 at index 4927
# New pivot high found: 208.1000061035156 at index 4928
# New pivot high found: 210.0 at index 4929
# New pivot high found: 212.0666656494141 at index 4930
# Threshold met. Returning pivot high index: 4930
# New pivot low found: 204.6999969482422 at index 4932
# New pivot low found: 202.5 at index 4933
# Threshold met. Returning pivot low index: 4933
# New pivot high found: 211.5333404541016 at index 4936
# Threshold met. Returning pivot high index: 4936
# New pivot low found: 208.0 at index 4938
# Threshold met. Returning pivot low index: 4938
# Threshold met. Returning pivot high index: 4939
# New pivot low found: 204.36666870117188 at index 4942
# Threshold met. Returning pivot low index: 4942
# New pivot high found: 211.0 at index 4944
# New pivot high found: 213.26666259765625 at index 4946
# New pivot high found: 215.93333435058597 at index 4947
# Threshold met. Returning pivot high index: 4947
# New pivot low found: 207.13333129882807 at index 4950
# New pivot low found: 206.5333404541016 at index 4953
# New pivot low found: 206.36666870117188 at index 4954
# New pivot low found: 200.3999938964844 at index 4955
# New pivot low found: 200.0 at index 4956
# Threshold met. Returning pivot low index: 4956
# New pivot high found: 222.3333282470703 at index 4958
# Threshold met. Returning pivot high index: 4958
# Threshold met. Returning pivot low index: 4959
# Threshold met. Returning pivot high index: 4960
# New pivot low found: 214.6666717529297 at index 4962
# New pivot low found: 212.8999938964844 at index 4963
# New pivot low found: 210.8999938964844 at index 4964
# New pivot low found: 210.6666717529297 at index 4965
# New pivot low found: 202.0 at index 4966
# Threshold met. Returning pivot low index: 4966
# Threshold met. Returning pivot high index: 4967
# New pivot low found: 206.0 at index 4970
# Threshold met. Returning pivot low index: 4970
# New pivot high found: 220.86666870117188 at index 4972
# Threshold met. Returning pivot high index: 4972
# New pivot low found: 208.3333282470703 at index 4974
# Threshold met. Returning pivot low index: 4974
# New pivot high found: 219.5666656494141 at index 4977
# Threshold met. Returning pivot high index: 4977
# New pivot low found: 209.5333404541016 at index 4979
# Threshold met. Returning pivot low index: 4979
# Threshold met. Returning pivot high index: 4981
# New pivot low found: 207.43333435058597 at index 4983
# New pivot low found: 206.86666870117188 at index 4984
# Threshold met. Returning pivot low index: 4984
# Threshold met. Returning pivot high index: 4985
# Threshold met. Returning pivot low index: 4986
# Threshold met. Returning pivot high index: 4987
# Threshold met. Returning pivot low index: 4988
# New pivot high found: 215.23333740234372 at index 4990
# New pivot high found: 218.6666717529297 at index 4991
# Threshold met. Returning pivot high index: 4991
# New pivot low found: 206.6666717529297 at index 4993
# New pivot low found: 204.6666717529297 at index 4994
# Threshold met. Returning pivot low index: 4994
# New pivot high found: 216.6666717529297 at index 4996
# Threshold met. Returning pivot high index: 4996
# Threshold met. Returning pivot low index: 4997
# New pivot high found: 222.5666656494141 at index 4999
# Threshold met. Returning pivot high index: 4999
# Threshold met. Returning pivot low index: 5000
# New pivot high found: 233.3333282470703 at index 5002
# Threshold met. Returning pivot high index: 5002
# Threshold met. Returning pivot low index: 5003
# New pivot high found: 234.93333435058597 at index 5008
# Threshold met. Returning pivot high index: 5008
# Threshold met. Returning pivot low index: 5009
# New pivot high found: 239.3000030517578 at index 5013
# New pivot high found: 239.86666870117188 at index 5014
# Threshold met. Returning pivot high index: 5014
# Threshold met. Returning pivot low index: 5015
# Threshold met. Returning pivot high index: 5016
# New pivot low found: 220.6000061035156 at index 5018
# New pivot low found: 219.96665954589844 at index 5019
# Threshold met. Returning pivot low index: 5019
# New pivot high found: 230.0333404541016 at index 5025
# Threshold met. Returning pivot high index: 5025
# Threshold met. Returning pivot low index: 5026
# New pivot high found: 233.5 at index 5028
# New pivot high found: 234.1000061035156 at index 5029
# New pivot high found: 235.3333282470703 at index 5030
# Threshold met. Returning pivot high index: 5030
# New pivot low found: 224.1666717529297 at index 5032
# New pivot low found: 221.5333404541016 at index 5033
# Threshold met. Returning pivot low index: 5033
# New pivot high found: 231.1999969482422 at index 5036
# New pivot high found: 231.3333282470703 at index 5037
# New pivot high found: 233.1666717529297 at index 5038
# Threshold met. Returning pivot high index: 5038
# New pivot low found: 223.3333282470703 at index 5040
# New pivot low found: 207.0333404541016 at index 5041
# New pivot low found: 205.76666259765625 at index 5063
# Threshold met. Returning pivot low index: 5063
# New pivot high found: 213.6000061035156 at index 5067
# Threshold met. Returning pivot high index: 5067
# New pivot low found: 207.96665954589844 at index 5071
# New pivot low found: 203.3333282470703 at index 5072
# New pivot low found: 202.43333435058597 at index 5073
# New pivot low found: 201.73333740234372 at index 5074
# Threshold met. Returning pivot low index: 5074
# New pivot high found: 214.5666656494141 at index 5077
# New pivot high found: 217.3333282470703 at index 5078
# Threshold met. Returning pivot high index: 5078
# Threshold met. Returning pivot low index: 5079
# Threshold met. Returning pivot high index: 5080
# Threshold met. Returning pivot low index: 5081
# New pivot high found: 217.3000030517578 at index 5083
# Threshold met. Returning pivot high index: 5083
# New pivot low found: 206.5 at index 5085
# New pivot low found: 204.6666717529297 at index 5086
# New pivot low found: 198.3000030517578 at index 5087
# New pivot low found: 195.76666259765625 at index 5090
# New pivot low found: 192.6999969482422 at index 5091
# Threshold met. Returning pivot low index: 5091
# Threshold met. Returning pivot high index: 5092
# New pivot low found: 195.1000061035156 at index 5095
# New pivot low found: 190.6666717529297 at index 5096
# New pivot low found: 189.3333282470703 at index 5097
# Threshold met. Returning pivot low index: 5097
# New pivot high found: 201.1000061035156 at index 5099
# New pivot high found: 218.0 at index 5100
# New pivot high found: 222.6000061035156 at index 5101
# Threshold met. Returning pivot high index: 5101
# New pivot low found: 209.8333282470703 at index 5103
# Threshold met. Returning pivot low index: 5103
# Threshold met. Returning pivot high index: 5104
# Threshold met. Returning pivot low index: 5105
# New pivot high found: 214.6666717529297 at index 5107
# New pivot high found: 217.3333282470703 at index 5108
# Threshold met. Returning pivot high index: 5108
# Threshold met. Returning pivot low index: 5109
# New pivot high found: 224.13333129882807 at index 5113
# Threshold met. Returning pivot high index: 5113
# New pivot low found: 213.5666656494141 at index 5115
# New pivot low found: 213.5333404541016 at index 5116
# New pivot low found: 212.6666717529297 at index 5117
# Threshold met. Returning pivot low index: 5117
# New pivot high found: 221.6666717529297 at index 5119
# New pivot high found: 224.5333404541016 at index 5120
# Threshold met. Returning pivot high index: 5120
# New pivot low found: 212.6666717529297 at index 5124
# New pivot low found: 211.3333282470703 at index 5126
# Threshold met. Returning pivot low index: 5126
# New pivot high found: 225.5666656494141 at index 5129
# Threshold met. Returning pivot high index: 5129
# New pivot low found: 216.3000030517578 at index 5132
# New pivot low found: 213.6000061035156 at index 5133
# New pivot low found: 208.3333282470703 at index 5134
# Threshold met. Returning pivot low index: 5134
# Threshold met. Returning pivot high index: 5135
# New pivot low found: 213.3999938964844 at index 5137
# New pivot low found: 212.93333435058597 at index 5138
# New pivot low found: 209.3333282470703 at index 5139
# New pivot low found: 206.76666259765625 at index 5140
# Threshold met. Returning pivot low index: 5140
# Threshold met. Returning pivot high index: 5141
# Threshold met. Returning pivot low index: 5142
# New pivot high found: 217.3333282470703 at index 5144
# Threshold met. Returning pivot high index: 5144
# New pivot low found: 210.0666656494141 at index 5146
# Threshold met. Returning pivot low index: 5146
# New pivot high found: 220.0 at index 5148
# New pivot high found: 222.3000030517578 at index 5149
# New pivot high found: 223.1999969482422 at index 5150
# Threshold met. Returning pivot high index: 5150
# Threshold met. Returning pivot low index: 5151
# New pivot high found: 236.3333282470703 at index 5153
# New pivot high found: 238.3000030517578 at index 5155
# New pivot high found: 242.6666717529297 at index 5156
# Threshold met. Returning pivot high index: 5156
# New pivot low found: 232.8333282470703 at index 5159
# Threshold met. Returning pivot low index: 5159
# Threshold met. Returning pivot high index: 5160
# New pivot low found: 234.23333740234372 at index 5163
# Threshold met. Returning pivot low index: 5163
# New pivot high found: 243.3333282470703 at index 5165
# Threshold met. Returning pivot high index: 5165
# New pivot low found: 233.36666870117188 at index 5167
# New pivot low found: 230.43333435058597 at index 5168
# Threshold met. Returning pivot low index: 5168
# New pivot high found: 240.0 at index 5170
# Threshold met. Returning pivot high index: 5170
# Threshold met. Returning pivot low index: 5171
# New pivot high found: 240.6666717529297 at index 5173
# Threshold met. Returning pivot high index: 5173
# Threshold met. Returning pivot low index: 5175
# Threshold met. Returning pivot high index: 5176
# Threshold met. Returning pivot low index: 5177
# New pivot high found: 246.1000061035156 at index 5179
# New pivot high found: 246.63333129882807 at index 5180
# New pivot high found: 247.8000030517578 at index 5181
# New pivot high found: 259.75 at index 5182
# Threshold met. Returning pivot high index: 5182
# Threshold met. Returning pivot low index: 5184
# Threshold met. Returning pivot high index: 5185
# Threshold met. Returning pivot low index: 5186
# New pivot high found: 251.9499969482422 at index 5188
# Threshold met. Returning pivot high index: 5188
# New pivot low found: 245.1000061035156 at index 5190
# Threshold met. Returning pivot low index: 5190
# Threshold met. Returning pivot high index: 5191
# Threshold met. Returning pivot low index: 5193
# New pivot high found: 253.5 at index 5195
# New pivot high found: 256.20001220703125 at index 5196
# Threshold met. Returning pivot high index: 5196
# Threshold met. Returning pivot low index: 5199
# New pivot high found: 256.5 at index 5201
# Threshold met. Returning pivot high index: 5201
# Threshold met. Returning pivot low index: 5202
# Threshold met. Returning pivot high index: 5203
# Threshold met. Returning pivot low index: 5205
# Threshold met. Returning pivot high index: 5206
# New pivot low found: 246.1000061035156 at index 5208
# New pivot low found: 245.8000030517578 at index 5209
# Threshold met. Returning pivot low index: 5209
# New pivot high found: 255.5 at index 5211
# New pivot high found: 258.0 at index 5212
# Threshold met. Returning pivot high index: 5212
# New pivot low found: 251.5 at index 5214
# New pivot low found: 249.75 at index 5215
# Threshold met. Returning pivot low index: 5215
# New pivot high found: 255.0 at index 5217
# Threshold met. Returning pivot high index: 5217
# Threshold met. Returning pivot low index: 5218
# New pivot high found: 257.8999938964844 at index 5222
# New pivot high found: 261.5 at index 5223
# New pivot high found: 263.0 at index 5224
# New pivot high found: 263.70001220703125 at index 5225
# New pivot high found: 265.8999938964844 at index 5226
# Threshold met. Returning pivot high index: 5226
# New pivot low found: 251.75 at index 5230
# New pivot low found: 249.5500030517578 at index 5231
# Threshold met. Returning pivot low index: 5231
# New pivot high found: 262.20001220703125 at index 5233
# New pivot high found: 262.6000061035156 at index 5234
# Threshold met. Returning pivot high index: 5234
# New pivot low found: 253.0 at index 5236
# New pivot low found: 251.8000030517578 at index 5238
# ...
# New pivot low found: 257.54998779296875 at index 6613
# New pivot low found: 252.5 at index 6616
# Threshold met. Returning pivot low index: 6616
# Threshold met. Returning pivot high index: 6617
# Threshold met. Returning pivot low index: 6618
# New pivot high found: 264.5 at index 6621
# New pivot high found: 266.04998779296875 at index 6622
# New pivot high found: 267.3500061035156 at index 6624
# Threshold met. Returning pivot high index: 6624
# New pivot low found: 249.1499938964844 at index 6628
# Threshold met. Returning pivot low index: 6628
# Threshold met. Returning pivot high index: 6629
# Threshold met. Returning pivot low index: 6630
# New pivot high found: 267.79998779296875 at index 6632
# New pivot high found: 279.25 at index 6633
# New pivot high found: 282.3500061035156 at index 6634
# Threshold met. Returning pivot high index: 6634
# New pivot low found: 270.0 at index 6636
# New pivot low found: 263.8500061035156 at index 6638
# Threshold met. Returning pivot low index: 6638
# New pivot high found: 271.0 at index 6640
# New pivot high found: 274.5 at index 6641
# New pivot high found: 275.70001220703125 at index 6644
# New pivot high found: 275.79998779296875 at index 6645
# Threshold met. Returning pivot high index: 6645
# New pivot low found: 265.75 at index 6648
# New pivot low found: 263.0 at index 6650
# New pivot low found: 259.5 at index 6653
# New pivot low found: 258.54998779296875 at index 6654
# Threshold met. Returning pivot low index: 6654
# New pivot high found: 270.8500061035156 at index 6656
# Threshold met. Returning pivot high index: 6656
# Threshold met. Returning pivot low index: 6658
# New pivot high found: 270.6499938964844 at index 6660
# New pivot high found: 272.25 at index 6661
# New pivot high found: 275.0 at index 6662
# New pivot high found: 285.0 at index 6664
# New pivot high found: 293.29998779296875 at index 6665
# Threshold met. Returning pivot high index: 6966
# New pivot low found: 442.25 at index 6968
# New pivot low found: 438.3500061035156 at index 6969
# Threshold met. Returning pivot low index: 6969
# New pivot high found: 449.9500122070313 at index 6972
# Threshold met. Returning pivot high index: 6972
# New pivot low found: 433.2999877929688 at index 6975
# Threshold met. Returning pivot low index: 6975
# New pivot high found: 444.8500061035156 at index 6979
# New pivot high found: 449.4500122070313 at index 6980
# New pivot high found: 452.5 at index 6981
# New pivot high found: 454.5 at index 6984
# New pivot high found: 458.2000122070313 at index 6985
# Threshold met. Returning pivot high index: 6985
# New pivot low found: 437.3500061035156 at index 6987
# New pivot low found: 433.1000061035156 at index 6988
# New pivot low found: 427.0499877929688 at index 6989
# New pivot low found: 425.5 at index 6994
# Threshold met. Returning pivot low index: 6994
# New pivot high found: 434.3999938964844 at index 6996
# New pivot high found: 436.7999877929688 at index 6997
# Threshold met. Returning pivot high index: 6997
# Threshold met. Returning pivot low index: 6998
# New pivot high found: 438.0 at index 7000
# Threshold met. Returning pivot high index: 7000
# Threshold met. Returning pivot low index: 7001
# New pivot high found: 442.5 at index 7003
# New pivot high found: 444.5 at index 7004
# Threshold met. Returning pivot high index: 7004
# Threshold met. Returning pivot low index: 7006
# New pivot high found: 442.25 at index 7009
# Threshold met. Returning pivot high index: 7009
# New pivot low found: 434.8999938964844 at index 7011
# New pivot low found: 434.1499938964844 at index 7012
# Threshold met. Returning pivot low index: 7012
# New pivot high found: 456.3999938964844 at index 7015
# New pivot high found: 457.7999877929688 at index 7016
# New pivot high found: 464.5 at index 7017
# New pivot high found: 464.7999877929688 at index 7018
# Threshold met. Returning pivot high index: 7018
# Threshold met. Returning pivot low index: 7019
# Threshold met. Returning pivot high index: 7024
# Threshold met. Returning pivot low index: 7025
# New pivot high found: 459.25 at index 7027
# Threshold met. Returning pivot high index: 7027
# Threshold met. Returning pivot low index: 7028
# New pivot high found: 458.8999938964844 at index 7030
# Threshold met. Returning pivot high index: 7030
# Threshold met. Returning pivot low index: 7031
# New pivot high found: 467.8999938964844 at index 7033
# New pivot high found: 469.9500122070313 at index 7034
# New pivot high found: 471.3500061035156 at index 7035
# New pivot high found: 480.7000122070313 at index 7036
# New pivot high found: 481.4500122070313 at index 7037
# Threshold met. Returning pivot high index: 7037
# New pivot low found: 464.5499877929688 at index 7039
# New pivot low found: 463.6499938964844 at index 7040
# New pivot low found: 460.0499877929688 at index 7041
# Threshold met. Returning pivot low index: 7041
# New pivot high found: 470.5 at index 7044
# New pivot high found: 475.0 at index 7045
# New pivot high found: 477.0 at index 7046
# Threshold met. Returning pivot high index: 7046
# Threshold met. Returning pivot low index: 7047
# New pivot high found: 473.75 at index 7050
# Threshold met. Returning pivot high index: 7050
# New pivot low found: 447.5 at index 7053
# New pivot low found: 437.3999938964844 at index 7054
# New pivot low found: 436.5499877929688 at index 7058
# New pivot low found: 429.5 at index 7059
# New pivot low found: 408.6000061035156 at index 7061

# %%
df_last_3_months.index.min()
# Out:
# 3981

# %%
get_index("2023-02-24", df_last_3_months )
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624
#  (5175, 235.0333404541016, 'LOW'),
#  (5176, 241.0, 'HIGH'),
#  (5177, 233.46665954589844, 'LOW'),
#  (5182, 259.75, 'HIGH'),
#  (5184, 242.1999969482422, 'LOW'),
#  (5185, 248.6499938964844, 'HIGH'),
#  (5186, 242.5, 'LOW'),
#  (5188, 251.9499969482422, 'HIGH'),
#  (5190, 245.1000061035156, 'LOW'),
#  (5191, 252.5500030517578, 'HIGH'),
#  (5193, 245.6000061035156, 'LOW'),
#  (5196, 256.20001220703125, 'HIGH'),
#  (5199, 246.3000030517578, 'LOW'),
#  (5201, 256.5, 'HIGH'),
#  (5202, 249.5500030517578, 'LOW'),
#  (5203, 262.0, 'HIGH'),
#  (5205, 250.1999969482422, 'LOW'),
#  (5206, 256.5, 'HIGH'),
#  (5209, 245.8000030517578, 'LOW'),
#  (5212, 258.0, 'HIGH'),
#  (5215, 249.75, 'LOW'),
#  (5217, 255.0, 'HIGH'),
#  (5218, 249.1000061035156, 'LOW'),
#  (5226, 265.8999938964844, 'HIGH'),
#  (5231, 249.5500030517578, 'LOW'),
#  (5234, 262.6000061035156, 'HIGH'),
#  (5240, 245.0, 'LOW'),
#  (5241, 249.3999938964844, 'HIGH'),
#  (5247, 235.6499938964844, 'LOW'),
#  (5249, 242.6000061035156, 'HIGH'),
#  (5250, 236.9499969482422, 'LOW'),
#  (5253, 246.5500030517578, 'HIGH'),
#  (5255, 238.1000061035156, 'LOW'),
#  (5258, 242.8999938964844, 'HIGH'),
#  (5259, 233.5, 'LOW'),
#  (5260, 244.8000030517578, 'HIGH'),
#  (5263, 235.1000061035156, 'LOW'),
#  (5266, 259.6499938964844, 'HIGH'),
#  (5278, 222.1000061035156, 'LOW'),
#  (5281, 235.6499938964844, 'HIGH'),
#  (5282, 229.1499938964844, 'LOW'),
#  (5283, 235.0, 'HIGH'),
#  (5287, 226.5, 'LOW'),
#  (5289, 239.6000061035156, 'HIGH'),
#  (5290, 231.9499969482422, 'LOW'),
#  (5291, 236.8999938964844, 'HIGH'),
#  (5295, 225.3500061035156, 'LOW'),
#  (5296, 230.8000030517578, 'HIGH'),
#  (5300, 222.0, 'LOW'),
#  (5309, 249.0, 'HIGH'),
#  (5310, 242.1000061035156, 'LOW'),
#  (5312, 250.5, 'HIGH'),
#  (5314, 242.5, 'LOW'),
#  (5323, 266.95001220703125, 'HIGH'),
#  (5325, 254.6000061035156, 'LOW'),
#  (5330, 292.1499938964844, 'HIGH'),
#  (5340, 260.79998779296875, 'LOW'),
#  (5342, 268.20001220703125, 'HIGH'),
#  (5343, 257.8500061035156, 'LOW'),
#  (5346, 270.25, 'HIGH'),
#  (5347, 258.1499938964844, 'LOW'),
#  (5348, 265.04998779296875, 'HIGH'),
#  (5349, 261.1499938964844, 'LOW'),
#  (5356, 288.8999938964844, 'HIGH'),
#  (5360, 275.1000061035156, 'LOW'),
#  (5361, 283.0, 'HIGH'),
#  (5362, 276.29998779296875, 'LOW'),
#  (5365, 284.6499938964844, 'HIGH'),
#  (5370, 270.8999938964844, 'LOW'),
#  (5373, 284.79998779296875, 'HIGH'),
#  (5375, 275.54998779296875, 'LOW'),
#  (5376, 284.0, 'HIGH'),
#  (5380, 271.1499938964844, 'LOW'),
#  (5382, 292.8999938964844, 'HIGH'),
#  (5386, 275.5, 'LOW'),
#  (5387, 282.20001220703125, 'HIGH'),
#  (5390, 271.0, 'LOW'),
#  (5396, 284.3999938964844, 'HIGH'),
#  (5397, 277.04998779296875, 'LOW'),
#  (5408, 319.8999938964844, 'HIGH'),
#  (5416, 299.1499938964844, 'LOW'),
#  (5420, 312.20001220703125, 'HIGH'),
#  (5421, 307.20001220703125, 'LOW'),
#  (5424, 316.5, 'HIGH'),
#  (5425, 307.1000061035156, 'LOW'),
#  (5428, 354.79998779296875, 'HIGH'),
#  (5430, 330.25, 'LOW'),
#  (5431, 338.75, 'HIGH'),
#  (5435, 327.3999938964844, 'LOW'),
#  (5437, 339.95001220703125, 'HIGH'),
#  (5439, 276.3999938964844, 'LOW'),
#  (5441, 294.8999938964844, 'HIGH'),
#  (5442, 286.54998779296875, 'LOW'),
#  (5446, 295.3999938964844, 'HIGH'),
#  (5457, 270.1000061035156, 'LOW'),
#  (5462, 285.0, 'HIGH'),
#  (5463, 280.3500061035156, 'LOW'),
#  (5464, 285.6000061035156, 'HIGH'),
#  (5466, 279.29998779296875, 'LOW'),
#  (5470, 284.3500061035156, 'HIGH'),
#  (5474, 269.54998779296875, 'LOW'),
#  (5477, 278.25, 'HIGH'),
#  (5482, 264.1000061035156, 'LOW'),
#  (5484, 272.3999938964844, 'HIGH'),
#  (5488, 256.79998779296875, 'LOW'),
#  (5493, 269.3999938964844, 'HIGH'),
#  (5498, 264.0, 'LOW'),
#  (5508, 276.0, 'HIGH'),
#  (5509, 263.45001220703125, 'LOW'),
#  (5511, 271.20001220703125, 'HIGH'),
#  (5521, 250.3999938964844, 'LOW'),
#  (5524, 260.70001220703125, 'HIGH'),
#  (5525, 255.1999969482422, 'LOW'),
#  (5528, 261.45001220703125, 'HIGH'),
#  (5532, 254.6499938964844, 'LOW'),
#  (5533, 259.6000061035156, 'HIGH'),
#  (5537, 250.0, 'LOW'),
#  (5539, 267.5, 'HIGH'),
#  (5542, 257.54998779296875, 'LOW'),
#  (5543, 267.04998779296875, 'HIGH'),
#  (5544, 259.04998779296875, 'LOW'),
#  (5547, 265.8999938964844, 'HIGH'),
#  (5551, 261.04998779296875, 'LOW'),
#  (5553, 266.29998779296875, 'HIGH'),
#  (5554, 260.45001220703125, 'LOW'),
#  (5560, 274.0, 'HIGH'),
#  (5565, 259.54998779296875, 'LOW'),
#  (5572, 283.29998779296875, 'HIGH'),
#  (5584, 264.79998779296875, 'LOW'),
#  (5585, 270.75, 'HIGH'),
#  (5587, 262.1499938964844, 'LOW'),
#  (5590, 270.0, 'HIGH'),
#  (5597, 253.5500030517578, 'LOW'),
#  (5601, 272.0, 'HIGH'),
#  (5606, 257.5, 'LOW'),
#  (5607, 261.6499938964844, 'HIGH'),
#  (5610, 252.5, 'LOW'),
#  (5611, 260.5, 'HIGH'),
#  (5612, 254.3500061035156, 'LOW'),
#  (5614, 260.0, 'HIGH'),
#  (5616, 255.5, 'LOW'),
#  (5619, 268.70001220703125, 'HIGH'),
#  (5622, 260.0, 'LOW'),
#  (5626, 280.0, 'HIGH'),
#  (5630, 272.70001220703125, 'LOW'),
#  (5635, 289.70001220703125, 'HIGH'),
#  (5636, 275.8500061035156, 'LOW'),
#  (5642, 287.29998779296875, 'HIGH'),
#  (5651, 268.75, 'LOW'),
#  (5653, 277.75, 'HIGH'),
#  (5658, 266.8500061035156, 'LOW'),
#  (5660, 272.29998779296875, 'HIGH'),
#  (5661, 267.0, 'LOW'),
#  (5663, 274.6000061035156, 'HIGH'),
#  (5672, 259.75, 'LOW'),
#  (5673, 266.1499938964844, 'HIGH'),
#  (5675, 259.0, 'LOW'),
#  (5676, 267.54998779296875, 'HIGH'),
#  (5677, 260.04998779296875, 'LOW'),
#  (5684, 280.29998779296875, 'HIGH'),
#  (5690, 266.25, 'LOW'),
#  (5693, 287.0, 'HIGH'),
#  (5694, 283.20001220703125, 'LOW'),
#  (5708, 310.20001220703125, 'HIGH'),
#  (5709, 305.1000061035156, 'LOW'),
#  (5712, 317.0, 'HIGH'),
#  (5714, 307.0, 'LOW'),
#  (5716, 315.79998779296875, 'HIGH'),
#  (5717, 310.0, 'LOW'),
#  (5720, 322.95001220703125, 'HIGH'),
#  (5721, 307.0, 'LOW'),
#  (5722, 314.45001220703125, 'HIGH'),
#  (5723, 308.04998779296875, 'LOW'),
#  (5724, 313.20001220703125, 'HIGH'),
#  (5727, 295.3999938964844, 'LOW'),
#  (5728, 308.6499938964844, 'HIGH'),
#  (5731, 298.0, 'LOW'),
#  (5732, 306.6000061035156, 'HIGH'),
#  (5736, 289.5, 'LOW'),
#  (5738, 302.95001220703125, 'HIGH'),
#  (5745, 263.6499938964844, 'LOW'),
#  (5751, 293.1000061035156, 'HIGH'),
#  (5758, 272.8500061035156, 'LOW'),
#  (5760, 285.95001220703125, 'HIGH'),
#  (5766, 273.1499938964844, 'LOW'),
#  (5771, 286.6499938964844, 'HIGH'),
#  (5773, 279.6000061035156, 'LOW'),
#  (5778, 290.0, 'HIGH'),
#  (5782, 271.5, 'LOW'),
#  (5783, 276.20001220703125, 'HIGH'),
#  (5785, 268.20001220703125, 'LOW'),
#  (5792, 284.3999938964844, 'HIGH'),
#  (5795, 274.79998779296875, 'LOW'),
#  (5797, 284.0, 'HIGH'),
#  (5800, 277.54998779296875, 'LOW'),
#  (5807, 296.0, 'HIGH'),
#  (5808, 290.0, 'LOW'),
#  (5809, 297.3999938964844, 'HIGH'),
#  (5818, 274.20001220703125, 'LOW'),
#  (5820, 280.20001220703125, 'HIGH'),
#  (5821, 273.6000061035156, 'LOW'),
#  (5822, 285.20001220703125, 'HIGH'),
#  (5824, 272.5, 'LOW'),
#  (5827, 281.20001220703125, 'HIGH'),
#  (5828, 268.45001220703125, 'LOW'),
#  (5832, 282.45001220703125, 'HIGH'),
#  (5837, 273.0, 'LOW'),
#  (5848, 297.0, 'HIGH'),
#  (5850, 289.3500061035156, 'LOW'),
#  (5853, 301.95001220703125, 'HIGH'),
#  (5856, 291.04998779296875, 'LOW'),
#  (5858, 302.0, 'HIGH'),
#  (5864, 291.70001220703125, 'LOW'),
#  (5869, 310.0, 'HIGH'),
#  (5874, 298.5, 'LOW'),
#  (5875, 309.79998779296875, 'HIGH'),
#  (5877, 299.5, 'LOW'),
#  (5881, 309.5, 'HIGH'),
#  (5885, 287.70001220703125, 'LOW'),
#  (5891, 310.0, 'HIGH'),
#  (5900, 275.29998779296875, 'LOW'),
#  (5901, 282.1499938964844, 'HIGH'),
#  (5903, 274.20001220703125, 'LOW'),
#  (5905, 281.3999938964844, 'HIGH'),
#  (5910, 274.0, 'LOW'),
#  (5911, 278.8999938964844, 'HIGH'),
#  (5913, 273.25, 'LOW'),
#  (5915, 280.0, 'HIGH'),
#  (5918, 272.5, 'LOW'),
#  (5919, 276.25, 'HIGH'),
#  (5921, 272.1499938964844, 'LOW'),
#  (5924, 282.8999938964844, 'HIGH'),
#  (5926, 270.75, 'LOW'),
#  (5927, 276.8999938964844, 'HIGH'),
#  (5934, 264.0, 'LOW'),
#  (5936, 273.3500061035156, 'HIGH'),
#  (5947, 253.0, 'LOW'),
#  (5948, 258.8500061035156, 'HIGH'),
#  (5949, 244.0, 'LOW'),
#  (5952, 257.29998779296875, 'HIGH'),
#  (5956, 234.6499938964844, 'LOW'),
#  (5959, 247.6499938964844, 'HIGH'),
#  (5972, 234.0500030517578, 'LOW'),
#  (5975, 260.5, 'HIGH'),
#  (5977, 242.6999969482422, 'LOW'),
#  (5983, 263.8999938964844, 'HIGH'),
#  (5987, 241.1000061035156, 'LOW'),
#  (5989, 249.1999969482422, 'HIGH'),
#  (5990, 242.1499938964844, 'LOW'),
#  (6002, 264.95001220703125, 'HIGH'),
#  (6003, 258.6000061035156, 'LOW'),
#  (6005, 266.29998779296875, 'HIGH'),
#  (6014, 245.0500030517578, 'LOW'),
#  (6015, 252.6499938964844, 'HIGH'),
#  (6016, 246.25, 'LOW'),
#  (6017, 250.3999938964844, 'HIGH'),
#  (6023, 242.0, 'LOW'),
#  (6024, 247.5, 'HIGH'),
#  (6027, 235.0, 'LOW'),
#  (6034, 247.8999938964844, 'HIGH'),
#  (6038, 236.3500061035156, 'LOW'),
#  (6040, 240.8999938964844, 'HIGH'),
#  (6042, 237.1000061035156, 'LOW'),
#  (6044, 241.0, 'HIGH'),
#  (6047, 233.25, 'LOW'),
#  (6053, 243.8999938964844, 'HIGH'),
#  (6054, 239.3999938964844, 'LOW'),
#  (6055, 243.25, 'HIGH'),
#  (6058, 236.8999938964844, 'LOW'),
#  (6059, 239.1000061035156, 'HIGH'),
#  (6061, 230.5, 'LOW'),
#  (6064, 238.3999938964844, 'HIGH'),
#  (6065, 205.0, 'LOW'),
#  (6068, 219.8999938964844, 'HIGH'),
#  (6070, 210.0500030517578, 'LOW'),
#  (6071, 216.9499969482422, 'HIGH'),
#  (6076, 200.5, 'LOW'),
#  (6078, 208.5500030517578, 'HIGH'),
#  (6083, 192.0500030517578, 'LOW'),
#  (6084, 203.4499969482422, 'HIGH'),
#  (6092, 134.60000610351562, 'LOW'),
#  (6097, 176.5, 'HIGH'),
#  (6100, 139.0, 'LOW'),
#  (6111, 193.75, 'HIGH'),
#  (6116, 176.0, 'LOW'),
#  (6117, 184.0, 'HIGH'),
#  (6120, 178.0500030517578, 'LOW'),
#  (6122, 184.8999938964844, 'HIGH'),
#  (6127, 157.10000610351562, 'LOW'),
#  (6130, 173.60000610351562, 'HIGH'),
#  (6132, 161.14999389648438, 'LOW'),
#  (6138, 194.9499969482422, 'HIGH'),
#  (6139, 186.8999938964844, 'LOW'),
#  (6142, 205.25, 'HIGH'),
#  (6145, 195.0, 'LOW'),
#  (6148, 206.1999969482422, 'HIGH'),
#  (6154, 180.6999969482422, 'LOW'),
#  (6156, 187.9499969482422, 'HIGH'),
#  (6157, 183.1499938964844, 'LOW'),
#  (6161, 209.3999938964844, 'HIGH'),
#  (6173, 192.75, 'LOW'),
#  (6174, 200.0, 'HIGH'),
#  (6178, 191.5, 'LOW'),
#  (6181, 201.6999969482422, 'HIGH'),
#  (6187, 191.8999938964844, 'LOW'),
#  (6188, 195.8000030517578, 'HIGH'),
#  (6189, 191.6999969482422, 'LOW'),
#  (6193, 207.6999969482422, 'HIGH'),
#  (6200, 194.5500030517578, 'LOW'),
#  (6201, 199.1999969482422, 'HIGH'),
#  (6204, 193.6499938964844, 'LOW'),
#  (6207, 199.0, 'HIGH'),
#  (6208, 188.25, 'LOW'),
#  (6210, 193.25, 'HIGH'),
#  (6212, 180.8000030517578, 'LOW'),
#  (6213, 190.5500030517578, 'HIGH'),
#  (6214, 182.3000030517578, 'LOW'),
#  (6216, 186.5, 'HIGH'),
#  (6225, 166.14999389648438, 'LOW'),
#  (6227, 174.8000030517578, 'HIGH'),
#  (6229, 168.6999969482422, 'LOW'),
#  (6230, 174.60000610351562, 'HIGH'),
#  (6235, 166.35000610351562, 'LOW'),
#  (6236, 175.1999969482422, 'HIGH'),
#  (6240, 163.8000030517578, 'LOW'),
#  (6246, 171.60000610351562, 'HIGH'),
#  (6250, 163.35000610351562, 'LOW'),
#  (6261, 190.0, 'HIGH'),
#  (6264, 182.6999969482422, 'LOW'),
#  (6268, 197.9499969482422, 'HIGH'),
#  (6271, 192.3999938964844, 'LOW'),
#  (6280, 218.6000061035156, 'HIGH'),
#  (6286, 196.8999938964844, 'LOW'),
#  (6290, 213.5, 'HIGH'),
#  (6292, 208.5500030517578, 'LOW'),
#  (6294, 216.0, 'HIGH'),
#  (6298, 200.25, 'LOW'),
#  (6304, 222.0, 'HIGH'),
#  (6309, 206.8500061035156, 'LOW'),
#  (6310, 212.6499938964844, 'HIGH'),
#  (6313, 201.8000030517578, 'LOW'),
#  (6314, 223.5, 'HIGH'),
#  (6315, 215.6999969482422, 'LOW'),
#  (6841, 369.6499938964844, 'LOW'),
#  (6872, 433.4500122070313, 'HIGH'),
#  (6876, 416.0499877929688, 'LOW'),
#  (6878, 430.0, 'HIGH'),
#  (6881, 411.3500061035156, 'LOW'),
#  (6887, 451.7999877929688, 'HIGH'),
#  (6888, 441.0, 'LOW'),
#  (6889, 452.0, 'HIGH'),
#  (6897, 433.8500061035156, 'LOW'),
#  (6902, 455.8999938964844, 'HIGH'),
#  (6906, 442.7000122070313, 'LOW'),
#  (6907, 451.3999938964844, 'HIGH'),
#  (6908, 443.1499938964844, 'LOW'),
#  (6913, 480.6499938964844, 'HIGH'),
#  (6916, 463.7000122070313, 'LOW'),
#  (6926, 499.7000122070313, 'HIGH'),
#  (6927, 455.3999938964844, 'LOW'),
#  (6929, 475.1499938964844, 'HIGH'),
#  (6936, 450.9500122070313, 'LOW'),
#  (6938, 459.8999938964844, 'HIGH'),
#  (6940, 444.75, 'LOW'),
#  (6942, 457.3999938964844, 'HIGH'),
#  (6944, 438.5, 'LOW'),
#  (6947, 455.6499938964844, 'HIGH'),
#  (6953, 436.1000061035156, 'LOW'),
#  (6954, 445.0, 'HIGH'),
#  (6955, 436.6499938964844, 'LOW'),
#  (6958, 449.0, 'HIGH'),
#  (6959, 441.8500061035156, 'LOW'),
#  (6962, 457.0, 'HIGH'),
#  (6965, 446.2000122070313, 'LOW'),
#  (6966, 455.1000061035156, 'HIGH'),
#  (6969, 438.3500061035156, 'LOW'),
#  (6972, 449.9500122070313, 'HIGH'),
#  (6975, 433.2999877929688, 'LOW'),
#  (6985, 458.2000122070313, 'HIGH'),
#  (6994, 425.5, 'LOW'),
#  (6997, 436.7999877929688, 'HIGH'),
#  (6998, 432.1499938964844, 'LOW'),
#  (7000, 438.0, 'HIGH'),
#  (7001, 432.5, 'LOW'),
#  (7004, 444.5, 'HIGH'),
#  (7006, 434.5, 'LOW'),
#  (7009, 442.25, 'HIGH'),
#  (7012, 434.1499938964844, 'LOW'),
#  (7018, 464.7999877929688, 'HIGH'),
#  (7019, 448.5, 'LOW'),
#  (7024, 462.9500122070313, 'HIGH'),
#  (7025, 450.3500061035156, 'LOW'),
#  (7027, 459.25, 'HIGH'),
#  (7028, 444.4500122070313, 'LOW'),
#  (7030, 458.8999938964844, 'HIGH'),
#  (7031, 453.75, 'LOW'),
#  (7037, 481.4500122070313, 'HIGH'),
#  (7041, 460.0499877929688, 'LOW'),
#  (7046, 477.0, 'HIGH'),
#  (7047, 454.5499877929688, 'LOW'),
#  (7050, 473.75, 'HIGH'),
#  (7061, 408.6000061035156, 'LOW')]

# %% [markdown]
# **Step 4: ZigZag Plot**

# %%
import plotly.graph_objects as go

# Assuming df_last_3_months is your DataFrame with the last 3 months of OHLC data
# Assuming extreme_points is the output from zig_zag(df_last_3_months), now including extreme values

# Create the candlestick chart
fig = go.Figure(data=[go.Candlestick(x=df_last_3_months['Date'],
                                     open=df_last_3_months['Open'],
                                     high=df_last_3_months['High'],
                                     low=df_last_3_months['Low'],
                                     close=df_last_3_months['Close'],
                                     name='Candlestick')])

# # Loop through the extreme_points to plot the high and low points using their exact values
# for index, extreme_value, extreme_type in extreme_points:
#     fig.add_trace(go.Scatter(x=[df_last_3_months.loc[index, 'Date']],
#                              y=[extreme_value],
#                              mode='markers',
#                              marker=dict(color='Green' if extreme_type == "LOW" else 'Red', size=8),
#                              name=f"{extreme_type} point"))

# # Loop through the extreme_points2 to plot the high and low points using their exact values
# for index, extreme_value, extreme_type in extreme_points2:
#     fig.add_trace(go.Scatter(x=[df_last_3_months.loc[index, 'Date']],
#                              y=[extreme_value],
#                              mode='markers',
#                              marker=dict(color='Green' if extreme_type == "LOW" else 'Red', size=8),
#                              name=f"{extreme_type} point"))

# For the trendline, use the dates and extreme values directly from the extreme_points
pivot_dates = [df_last_3_months.loc[index, 'Date'] for index, _, _ in extreme_points]
pivot_values = [extreme_value for _, extreme_value, _ in extreme_points]

# For the trendline, use the dates and extreme values directly from the extreme_points
pivot_dates2 = [df_last_3_months.loc[index, 'Date'] for index, _, _ in extreme_points2]
pivot_values2 = [extreme_value for _, extreme_value, _ in extreme_points2]

# Add a line connecting the pivot points to represent the zigzag trend
fig.add_trace(go.Scatter(x=pivot_dates,
                         y=pivot_values,
                         mode='lines',  # This will connect the points with lines
                         line=dict(color='Yellow', width=2),
                         name='Zigzag Trend'))

# Add a line connecting the pivot points to represent the zigzag trend
fig.add_trace(go.Scatter(x=pivot_dates2,
                         y=pivot_values2,
                         mode='lines',  # This will connect the points with lines
                         line=dict(color='Red', width=2),
                         name='Zigzag Trend'))

# Customize the layout
fig.update_layout(title='Stock Price Data with Zigzag Trendlines',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False)

# Show the plot
fig.show()

# %% [markdown]
# # **Breather Identification**
# ---

# %% [markdown]
# **Step 1 : Uptrend_BREATHER_IDENTIFICATION**

# %%
def Uptrend_BREATHER_IDENTIFICATION(start_point, Extreme_points, length_of_previous_trend_move, uptrend_correction_threshold=0, uptrend_retest_boundary_threshold=0):

    """
    Assess if the correction next to start_point is a small breather and can be ignored.
    """
    # print(f"Starting Uptrend_BREATHER_IDENTIFICATION with start_point index: {start_point}")

    if Extreme_points[start_point][2] == "LOW":
        # print("Starting point is a LOW, which is not suitable for uptrend analysis. High Point needed.")
        return ("High Point needed", 0)

    if start_point == 0:
        # print("Start point is the first point in the series. No previous point to compute move length.")
        return ("No previous point to compute move length", 0)

    if start_point >= len(Extreme_points) - 1:
        # print("Start point is the last point in the series. No points to assess after start_point.")
        return ("Start Point is the End Point", 0)

    start_point_value = Extreme_points[start_point][1]

    # Calculate upper and lower limits for the breather identification
    upper_limit = (1 + uptrend_retest_boundary_threshold / 100) * start_point_value
    # Lower Limit based on percentage correction
    lower_limit = start_point_value - (uptrend_correction_threshold / 100) * start_point_value
    # Lower_limit based on length of trend move
    # lower_limit = start_point_value - (uptrend_correction_threshold / 100) * length_of_previous_trend_move

    # print(f"Upper limit: {upper_limit}, Lower limit: {lower_limit}, based on start_point_value: {start_point_value} and prev_point_value: {prev_point_value}")

    no_of_skips = 0

    for i in range(start_point + 1, len(Extreme_points)):
        next_point_value = Extreme_points[i][1]
        # print(f"Evaluating point at index {i} with value {next_point_value}")

        if next_point_value > upper_limit:
            # print(f"Point at index {i} exceeds the upper limit. Trend Continued.")
            return ("Trend Continued", no_of_skips)
        elif next_point_value < lower_limit:
            # print(f"Point at index {i} falls below the lower limit. Trend Reversed.")
            return ("Trend Reversed", no_of_skips)
        else:
            no_of_skips += 1
            # print(f"Point at index {i} is within breather thresholds. Continuing analysis...")

    # print("Reached the end of Extreme_points without determining trend continuation or reversal.")
    return ("Breather Continued without trend reversal or continuation", 0)

# %%
get_index('2023-07-24',df_last_3_months)
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 6926

# %%
# Example date from which you want to start the assessment
given_date = '2023-07-24'

df_index = get_index(given_date, df_last_3_months)

# Find the start point in Extreme_points based on the given date
start_point = None
for i, (index, value, point_type) in enumerate(extreme_points):
    if index == df_index:
        start_point = i
        break

if start_point is None:
    print("No start point found for the given date within the extreme points.")
else:
    length_of_previous_trend_move = extreme_points[start_point][1] - extreme_points[start_point - 1][1]
    uptrend_correction_threshold = 40  # Example threshold value
    uptrend_retest_boundary_threshold = 0  # Example threshold value

    trend_status, no_of_skips = Uptrend_BREATHER_IDENTIFICATION(start_point, extreme_points, length_of_previous_trend_move=length_of_previous_trend_move,  uptrend_correction_threshold= uptrend_correction_threshold, uptrend_retest_boundary_threshold = uptrend_retest_boundary_threshold)

    print(f"Trend status: {trend_status}, Number of skips: {no_of_skips}")
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Trend status: Breather Continued without trend reversal or continuation, Number of skips: 0

# %% [markdown]
# **Step 2 : Downtrend_BREATHER_IDENTIFICATION**

# %%
def Downtrend_BREATHER_IDENTIFICATION(start_point, Extreme_points, length_of_previous_trend_move, downtrend_correction_threshold=0, downtrend_retest_boundary_threshold=0):
    """
    Assess if the correction next to start_point in a downtrend is a small breather and can be ignored.

    Parameters:
    - start_point: The index of the point within the Extreme_points list.
    - Extreme_points: List of tuples containing (index, value, type) of extreme points.
    - length_of_previous_trend_move:  length of the move preceding the start_point
    - df: DataFrame containing the OHLC data.
    - downtrend_correction_threshold: Percentage threshold above which a correction is considered significant.
    - downtrend_retest_boundary_threshold: Percentage threshold below which the downtrend is considered continued.

    Returns:
    - A tuple containing trend_status ("Continued" / "Reversed" / None / "incomplete" / "End Point") and no_of_skips.
    """
    # print(f"Starting Down_BREATHER_IDENTIFICATION with start_point index: {start_point}")

    if start_point == 0 or start_point >= len(Extreme_points) - 1:
        if start_point == 0:
            # print("No previous point to compute move length.")
            return ("No previous point to compute move length", 0)
        else:
            # print("Start point is the last point in the series. No points to assess after start_point.")
            return ("Start Point is the End Point", 0)

    if Extreme_points[start_point][2] != "LOW":
        # print("Starting point is not a LOW, which is necessary for downtrend analysis. LOW Point needed.")
        return ("LOW Point needed", 0)

    start_point_low = Extreme_points[start_point][1]

    lower_limit = (1 - downtrend_retest_boundary_threshold / 100) * start_point_low
    # Upper_limit based on percentage of the start point
    upper_limit = start_point_low + (downtrend_correction_threshold / 100) * start_point_low

    # Upper_limit based on length of trend move
    # upper_limit = start_point_low + (downtrend_correction_threshold / 100) * length_of_previous_trend_move

    # print(f"Calculated lower_limit: {lower_limit}, upper_limit: {upper_limit} based on start_point_low: {start_point_low} and length_of_trend_move: {length_of_trend_move}")

    no_of_skips = 0

    for i in range(start_point + 1, len(Extreme_points)):
        next_point_value = Extreme_points[i][1]
        # print(f"Evaluating point at index {i} with value {next_point_value}")

        if next_point_value < lower_limit:
            # print(f"Point at index {i} falls below the lower limit. Trend Continued.")
            return ("Trend Continued", no_of_skips)
        elif next_point_value > upper_limit:
            # print(f"Point at index {i} exceeds the upper limit. Trend Reversed.")
            return ("Trend Reversed", no_of_skips)
        else:
            no_of_skips += 1
            # print(f"Point at index {i} is within the breather thresholds. Continuing analysis...")

    # print("Reached the end of Extreme_points without determining trend continuation or reversal.")
    return ("Breather Continued without trend reversal or continuation", 0)

# %%
# Example date from which you want to start the assessment
given_date = '2024-01-10'

df_index = get_index(given_date, df_last_3_months)

# Find the start point in Extreme_points based on the given date
start_point = None
for i, (index, value, point_type) in enumerate(extreme_points):
    if index == df_index:
        start_point = i
        break

if start_point is None:
    print("No start point found for the given date within the extreme points.")
else:
    length_of_previous_trend_move = extreme_points[start_point - 1][1] - extreme_points[start_point][1]
    downtrend_correction_threshold = 10  # Example threshold value
    downtrend_retest_boundary_threshold = 0  # Example threshold value

    trend_status, no_of_skips = Downtrend_BREATHER_IDENTIFICATION(start_point, extreme_points, length_of_previous_trend_move=length_of_previous_trend_move, downtrend_correction_threshold= downtrend_correction_threshold, downtrend_retest_boundary_threshold = downtrend_retest_boundary_threshold)

    print(f"Trend status: {trend_status}, Number of skips: {no_of_skips}")
# Out:
# No start point found for the given date within the extreme points.
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Step 2: BREATHER_FILTER**

# %%
def BREATHER_FILTER(Extreme_points, uptrend_correction_threshold, downtrend_correction_threshold, uptrend_retest_boundary_threshold, downtrend_retest_boundary_threshold):
    """
    Filters out small corrections in large trends from a list of extreme points.

    Parameters:
    - Extreme_points: List of tuples containing (index, value, type) of extreme points.
    - uptrend_correction_threshold: Percentage threshold for uptrend corrections.
    - downtrend_correction_threshold: Percentage threshold for downtrend corrections.
    - uptrend_retest_boundary_threshold: Percentage threshold for retesting in uptrends.
    - downtrend_retest_boundary_threshold: Percentage threshold for retesting in downtrends.

    Returns:
    - A filtered list of extreme points.
    """
    # Validation check to ensure Extreme_points is not empty
    if not Extreme_points:
        print("Extreme_points list is empty. No points available for filtering.")
        return []

    filtered_extreme_points = [Extreme_points[0]]  # Initialize with the first point

    i = 1  # Start from the second point
    while i < len(Extreme_points):
        current_point = Extreme_points[i]
        # print(f"Evaluating point at index {i}: {current_point}")

        if current_point[2] == "HIGH":
            length_of_previous_trend_move = current_point[1] - filtered_extreme_points[-1][1]
            trend_status, no_of_skips = Uptrend_BREATHER_IDENTIFICATION(i, Extreme_points, length_of_previous_trend_move, uptrend_correction_threshold, uptrend_retest_boundary_threshold)
        elif current_point[2] == "LOW":
            length_of_previous_trend_move = filtered_extreme_points[-1][1]  -  current_point[1]
            trend_status, no_of_skips = Downtrend_BREATHER_IDENTIFICATION(i, Extreme_points, length_of_previous_trend_move, downtrend_correction_threshold, downtrend_retest_boundary_threshold)

        # print(f"Trend status: {trend_status}, No of skips: {no_of_skips}")

        if trend_status == "Start Point is the End Point":
            filtered_extreme_points.append(current_point)
            return filtered_extreme_points
        elif trend_status == "Trend Reversed":
            filtered_extreme_points.append(current_point)
            i += no_of_skips + 1  # Move to the next extreme point for evaluation
        elif trend_status == "Trend Continued":
            i += no_of_skips + 1  # Skip minor correction points
        elif trend_status == "Breather Continued without trend reversal or continuation":
            # Include all points starting from current_point till the end
            filtered_extreme_points.extend(Extreme_points[i:])
            break

    return filtered_extreme_points

# %%
# Example usage:
# Assuming Extreme_points and thresholds are defined
uptrend_correction_threshold = 9.99
downtrend_correction_threshold = 9.99
filtered_extreme_points = BREATHER_FILTER(extreme_points, uptrend_correction_threshold=uptrend_correction_threshold,downtrend_correction_threshold=downtrend_correction_threshold, uptrend_retest_boundary_threshold=0.1, downtrend_retest_boundary_threshold=0.1)

# %% [markdown]
# **Plot the output**
# ---

# %%
import plotly.graph_objects as go

# Assuming df_last_3_months is your DataFrame with the last 3 months of OHLC data
# Assuming Extreme_points and filtered_extreme_points are already defined

# Create the candlestick chart
fig = go.Figure(data=[go.Candlestick(x=df_last_3_months['Date'],
                                     open=df_last_3_months['Open'],
                                     high=df_last_3_months['High'],
                                     low=df_last_3_months['Low'],
                                     close=df_last_3_months['Close'],
                                     name='Candlestick')])

# Function to extract date and value for plotting
def extract_date_value(points, df):
    # Corrected function to ensure 'idx' is defined in both comprehensions
    dates = [df.loc[idx, 'Date'] for idx, value, point_type in points if idx in df.index]
    values = [value for idx, value, point_type in points if idx in df.index]
    return dates, values

# Original Extreme Points (with trend lines)
dates, values = extract_date_value(extreme_points, df_last_3_months)
fig.add_trace(go.Scatter(x=dates, y=values, mode='lines+markers',
                         line=dict(color='Blue', width=2),
                         marker=dict(color='LightSkyBlue', size=1),
                         name='Original Trend'))

# Filtered Extreme Points (with trend lines)
filtered_dates, filtered_values = extract_date_value(filtered_extreme_points, df_last_3_months)
fig.add_trace(go.Scatter(x=filtered_dates, y=filtered_values, mode='lines+markers',
                         line=dict(color='DarkGreen', width=2),
                         marker=dict(color='Green', size=1),
                         name='Filtered Trend'))

# Customize the layout
fig.update_layout(title='Stock Price Data with Trends',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False)

# Show the plot
fig.show()

# %%
start_index = get_index('2023-11-01', df_last_3_months)
end_index = get_index('2024-01-04', df_last_3_months)
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # **Stage2 Identification**
# ---

# %% [markdown]
# **price Volume Trend Check**

# %%
import numpy as np

def priceVolumeTrendCheck(df, start_index, end_index, upDownHighVolumeRatioThreshold=1.25, upTickPercentile=0.75, DownTickPercentile=0.25, change_type='CLOSE'):
    """
    Assess the ratio of significant upticks to downticks with high volume in a given period within a stock DataFrame.

    Parameters:
    - df: DataFrame containing stock OHLC data and Volume.
    - start_index: Index in df from which the analysis period starts.
    - end_index: Index in df at which the analysis period ends.
    - upDownHighVolumeRatioThreshold: Threshold ratio of significant upticks to downticks with high volume.
    - upTickPercentile: Percentile threshold for considering an uptick significant.
    - DownTickPercentile: Percentile threshold for considering a downtick significant.
    - change_type: Method to calculate price change ('HIGH-LOW', 'CLOSE', 'OPEN-CLOSE').

    Returns:
    - Ratio of significant upticks with high volume to significant downticks with high volume.
    """

    # Validate that provided indices are within the DataFrame's bounds and in correct order
    if start_index not in df.index or end_index not in df.index or start_index > end_index:
        # print("Invalid start or end index. Please ensure indices are within DataFrame bounds and start_index <= end_index.")
        return None

    # Calculate the 10-day rolling average of volume for each day in the dataset
    # Ensures that the rolling average for the initial days can include data preceding the start_index
    df['Vol_10D_avg'] = df['Volume'].rolling(window=10, min_periods=1).mean()

    # Calculate price changes within the entire DataFrame based on the specified change_type
    if change_type == 'CLOSE':
        df['PriceChange'] = df['Close'].diff()  # Daily close price change
    elif change_type == 'OPEN-CLOSE':
        df['PriceChange'] = df['Close'] - df['Open']  # Intraday price change
    else:
        # print("Invalid change_type specified.")
        return None

    # Filter the DataFrame for the analysis period
    df_filtered = df.loc[start_index:end_index]

    # Initialize counters for significant upticks and downticks with high volume
    count_up_tick_high_vol = 0
    count_down_tick_high_vol = 0

    # Setting upTickThreshold
    upTickThreshold = df['PriceChange'].quantile(upTickPercentile)
    downTickThreshold = df['PriceChange'].quantile(DownTickPercentile)

    # Iterate over the filtered DataFrame to count significant upticks and downticks with high volume
    for idx, row in df_filtered.iterrows():
        # Check if the current day's volume is above its 10-day average
        if row['Volume'] > row['Vol_10D_avg']:
            # Check for significant upticks
            if row['PriceChange'] >= upTickThreshold:
                count_up_tick_high_vol += 1
            # Check for significant downticks
            elif row['PriceChange'] <= downTickThreshold:
                count_down_tick_high_vol += 1

    # Calculate and return the ratio of significant upticks to downticks with high volume
    if count_down_tick_high_vol == 0:  # Handle division by zero
        ratio = 999  # Use a high value to indicate an overwhelmingly positive trend
    else:
        ratio = count_up_tick_high_vol / count_down_tick_high_vol
    # print(f"Count of total ticks : {end_index - start_index}")
    # print(f"Count of significant upticks with high volume: {count_up_tick_high_vol}")
    # print(f"Count of significant downticks with high volume: {count_down_tick_high_vol}")
    # print(f"Ratio of upticks to downticks with high volume: {ratio}")

    return ratio

# %%
# Assuming df_last_3_months is loaded and get_index function is defined

# Obtain start and end indices for the analysis period
start_index = get_index('2023-11-01', df_last_3_months)
end_index = get_index('2024-01-04', df_last_3_months)
print(f"start_index : {start_index}")
print(f"end_index : {end_index}")

# Specify parameters for the analysis
upDownHighVolumeRatioThreshold = 1.25  # Threshold ratio of significant upticks to downticks with high volume
upTickPercentile = 0.75  # Percentile threshold for considering an uptick significant
DownTickPercentile = 0.25  # Percentile threshold for considering a downtick significant
change_type = 'CLOSE'  # Method to calculate price change

# Call priceVolumeTrendCheck function with the obtained indices and specified parameters
upDownHighVolumeRatio = priceVolumeTrendCheck(
    df_last_3_months,
    start_index,
    end_index,
    upDownHighVolumeRatioThreshold,
    upTickPercentile,
    DownTickPercentile,
    change_type
)

print("UpDownHighVolumeRatio:", upDownHighVolumeRatio)
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# start_index : 6994
# end_index : 7037
# UpDownHighVolumeRatio: 1.1428571428571428
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **moving Average Check**

# %%
import pandas as pd
import numpy as np

def movingAverageCheck(start_index, end_index, df, initial_noise_period_proportion=15):
    """
    Checks if the moving averages are in the correct order and if the 200-day MA is increasing,
    accounting for an initial noise period.

    Parameters:
    - start_index: The index from which to start the check.
    - end_index: The index at which to end the check.
    - df: DataFrame containing stock data.
    - initial_noise_period_proportion: Proportion of the total move considered as initial noise.

    Returns:
    - True if checks pass, False otherwise.
    """

    # Debug log for moving averages
    # print("Added moving averages to DataFrame with min_periods=1.")

    # Check 1: 200-day MA should be increasing
    for i in range(start_index + 1, end_index + 1):  # Start from the next day of start_index
        if df.at[i, 'MA200'] <= df.at[i - 1, 'MA200']:
            print(f"Check 1 failed: 200-day MA not increasing at index {i}. start_index @{start_index} & end_index @{end_index}")
            return False

    # Determine the initial noise period index
    total_time = end_index - start_index
    initial_noise_period_index = int(start_index + np.ceil(initial_noise_period_proportion / 100.0 * total_time))

    # Debug log for initial noise period index
    print(f"Initial noise period index: {initial_noise_period_index}.")

    # Check 2: After initial noise period, 50-day MA > 150-day MA > 200-day MA
    for i in range(initial_noise_period_index, end_index + 1):
        if not (df.at[i, 'MA50'] > df.at[i, 'MA150'] > df.at[i, 'MA200']):
            print(f"Check 2 failed: MA order incorrect at index {i}.")
            return False

    # If all checks pass
    return True

# %%
# Fetch start and end indices based on dates
start_index = get_index('2023-11-01', df_last_3_months)
end_index = get_index('2024-01-04', df_last_3_months)

# Call movingAverageCheck function
result = movingAverageCheck(start_index, end_index, df_last_3_months, initial_noise_period_proportion=10)

# Print the result
print("Moving averages check result:", result)
# Out:
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Initial noise period index: 6999.
# Check 2 failed: MA order incorrect at index 7002.
# Moving averages check result: False

# %% [markdown]
# **super up trend**

# %%
def superUpTrend(start_index, end_index, df, min_jump=30, min_time=10, max_time=320, min_slope=0.1, comparison_type='HIGH-LOW', TimeLookBack=None, priceVolumeThreshold=1.25):
    """
    Determine if there has been an exceptional rise in stock prices between two points in time.

    Parameters:
    - start_index, end_index: Indices defining the analysis period within the DataFrame.
    - df: DataFrame containing stock OHLC data and Volume.
    - min_jump: Minimum percentage jump in price to qualify as a super uptrend.
    - min_time, max_time: Minimum and maximum time (in candles) for the trend.
    - min_slope: Minimum slope of the price jump to qualify as a super uptrend.
    - comparison_type: 'HIGH-LOW' or 'CLOSE', determines how price jump is calculated.
    - TimeLookBack: Number of candles to look back from end_index to ensure stock is in new territory.
    - priceVolumeThreshold: Minimum price-volume trend ratio to qualify as a super uptrend.

    Returns:
    - JSON object containing analysis results.
    """
    output_json = {
        "superUpTrend": True,
        "price_jump": None,
        "time_taken": None,
        "slope": None,
        "desc": ""
    }

    # Calculate price jump and check if the stock is in new territory
    if comparison_type == 'HIGH-LOW':
        price_jump = (df.at[end_index, 'High'] - df.at[start_index, 'Low']) / df.at[start_index, 'Low'] * 100
        # Define the lookback period based on TimeLookBack and available data
        lookBackStart = max(end_index - TimeLookBack, df.index.min()) if TimeLookBack else df.index.min()
        # Use DataFrame to determine the maximum value in the lookback range directly
        maxLookBackHigh = df.loc[lookBackStart:end_index, 'High'].max()
        stockInNewTerritoryFlag = maxLookBackHigh >= df.at[end_index, 'High']
        # print(f"price jump is {price_jump}")
        # print(f"Max High in LookBack Range: {maxLookBackHigh} .... end index High: {df.at[end_index, 'High']}")

    else:  # 'CLOSE'
        price_jump = (df.at[end_index, 'Close'] - df.at[start_index, 'Close']) / df.at[start_index, 'Close'] * 100
        # Define the lookback period based on TimeLookBack and available data
        lookBackStart = max(end_index - TimeLookBack, df.index.min()) if TimeLookBack else df.index.min()
        # Use DataFrame to determine the maximum value in the lookback range directly
        maxLookBackClose = df.loc[lookBackStart:end_index, 'Close'].max()
        stockInNewTerritoryFlag = maxLookBackClose >= df.at[end_index, 'Close']
        # print(f"Max Close in LookBack Range: {maxLookBackClose} .... end index Close: {df.at[end_index, 'Close']}")


    #  In pandas, df.at provides a very fast and efficient way to access a scalar value by its row label and column label.
    #  This method is optimized for accessing a single value: if you know the row label and the column name, df.at is the recommended method to get or set the value at that position.

    # Calculate time taken and slope
    time_taken = end_index - start_index
    if time_taken > 0:
      slope = price_jump / time_taken
    else:
        slope = float('inf')
        print(f"end index is {end_index} and start index is {start_index}")
        print("SLOPE IS INFINITE..  SOME ERROR!!")

    # Check all conditions
    if price_jump < min_jump:
        output_json["superUpTrend"] = False
        output_json["desc"] += f"Price jump < {min_jump}%. "

    if (time_taken < min_time) or (max_time is not None and time_taken >= max_time):
        output_json["superUpTrend"] = False
        output_json["desc"] += f"Time taken {time_taken} not in range {min_time} & {max_time}. "

    if slope < min_slope:
        output_json["superUpTrend"] = False
        output_json["desc"] += f"Slope < {min_slope}. "

    if not stockInNewTerritoryFlag:
        output_json["superUpTrend"] = False
        output_json["desc"] += f"Stock is not in new territory in the last {TimeLookBack} candles. "

    if not movingAverageCheck(start_index, end_index, df, initial_noise_period_proportion = 15):
        output_json["superUpTrend"] = False
        output_json["desc"] += f"Moving average check is FAILED and time_taken is {time_taken}"

    # Call priceVolumeTrendCheck function with the obtained indices and specified parameters
    upDownHighVolumeRatio = priceVolumeTrendCheck(
        df, start_index, end_index, priceVolumeThreshold, 0.75, 0.25, 'CLOSE'
    )

    if upDownHighVolumeRatio < priceVolumeThreshold:
        output_json["superUpTrend"] = False
        output_json["desc"] += f"High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is {upDownHighVolumeRatio} < {priceVolumeThreshold}. "

    # Calculate max decline over 5-day periods directly
    df['5Day_Change'] = df['Low'] - df['High'].shift(-4)
    df['5Day_Pct_Change'] = df['5Day_Change'] / df['High'].shift(-4)*100
    filtered_df = df.loc[start_index : end_index]
    max_5day_downward_pct_change = filtered_df['5Day_Pct_Change'].min()

    # Calculate max decline over 1-day period directly
    df['1Day_Change'] = df['Low'] - df['High'].shift(-1)
    df['1Day_Pct_Change'] = df['1Day_Change'] / df['High'].shift(-1)*100
    filtered_df = df.loc[start_index : end_index]
    max_1day_downward_pct_change = filtered_df['1Day_Pct_Change'].min()

    # Update output_json with calculated values
    output_json.update({
        "price_jump": price_jump,
        "time_taken": time_taken,
        "slope": slope,
        "max_1D_decline": max_1day_downward_pct_change,
        "max_5D_decline": max_5day_downward_pct_change
    })
    print(f"output_json : {output_json}")

    return output_json

# %%
# Assuming df_last_3_months is your DataFrame and superUpTrend is defined as per previous instructions

# Obtain start and end indices for the analysis period
start_index = get_index('2023-11-01', df_last_3_months)
end_index = get_index('2024-01-04', df_last_3_months)

print(f"start_index : {start_index}")
print(f"end_index : {end_index}")

# Call the superUpTrend function with the obtained indices and specified parameters
result = superUpTrend(
    start_index=start_index,
    end_index=end_index,
    df=df_last_3_months,
    min_jump=10,
    min_time=10,
    max_time=None,
    min_slope=0.1,
    comparison_type='HIGH-LOW',
    TimeLookBack=60,  # Example: look back 60 candles from end_index to check if stock is in new territory
    priceVolumeThreshold=1.25
)

print(result)
# Out:
# start_index : 6994
# end_index : 7037
# Initial noise period index: 7001.
# Check 2 failed: MA order incorrect at index 7002.
# output_json : {'superUpTrend': False, 'price_jump': 13.149239061581977, 'time_taken': 43, 'slope': 0.3057962572460925, 'desc': 'Moving average check is FAILED and time_taken is 43High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.1428571428571428 < 1.25. ', 'max_1D_decline': -4.163014954883932, 'max_5D_decline': -6.458557588805166}
# {'superUpTrend': False, 'price_jump': 13.149239061581977, 'time_taken': 43, 'slope': 0.3057962572460925, 'desc': 'Moving average check is FAILED and time_taken is 43High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.1428571428571428 < 1.25. ', 'max_1D_decline': -4.163014954883932, 'max_5D_decline': -6.458557588805166}
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **NextLowPoint**

# %%
def NextLowPoint(start_point, extreme_points, price_jump, max_time_taken = 250):
    """
    Find the next significant low point and the subsequent high point that meets the price jump criterion.

    Parameters:
    - low_point_index: Index within extreme_points where the search begins.
    - extreme_points: Array of tuples containing extreme points (index, value, type).
    - price_jump: The minimum jump in percentage required to identify a probable high point.

    Returns:
    - Tuple of (NextLowPoint, ProbableHighPoint) where ProbableHighPoint could be None if not found.
    """

    current_low_point = start_point
    current_low_point_index = extreme_points[current_low_point][0]
    current_low_point_value = extreme_points[current_low_point][1]
    NextHighPoint = None

    # Outer loop is to iterate through the low_point if the first low_point does not give any result
    while True:
        # Inner loop is to iterate through the next high points given a fixed low point
        for i in range(current_low_point + 1, len(extreme_points)):
            evaluated_point = extreme_points[i]
            evaluated_point_index, evaluated_point_value, evaluated_point_type = extreme_points[i][0], extreme_points[i][1], extreme_points[i][2]
            evaluated_point = i

            if evaluated_point_type == "LOW":
                if evaluated_point_value <= current_low_point_value:
                    current_low_point = evaluated_point
                    current_low_point_index = evaluated_point_index
                    current_low_point_value = evaluated_point_value
                    NextHighPoint = None  # Reset because a new lower low point is found

            elif evaluated_point_type == "HIGH":
                print(f"supertrend called from low_point {current_low_point_index} and high_point is {evaluated_point_index}")
                result = superUpTrend(
                    start_index=current_low_point_index,
                    end_index=evaluated_point_index,
                    df=df,
                    min_jump=price_jump,
                    min_time=10,
                    max_time=None,
                    min_slope=0.1,
                    comparison_type='HIGH-LOW',
                    TimeLookBack=500,  # Example: look back 60 candles from end_index to check if stock is in new territory
                    priceVolumeThreshold=1.25
                )
                if result['superUpTrend']:
                    NextHighPointIndex = evaluated_point_index
                    NextHighPoint = evaluated_point
                    break  # Exit loop as the target high point is found
                else:
                    if result["time_taken"] > max_time_taken:
                        print("Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function")
                        max_time_exceeded = True
                        break

        if NextHighPoint is not None:
            # print(f"Next high point identified @ index {NextHighPoint} from current low point @ index {current_low_point}")
            # break the while loop
            break

        else:
            print(f"No good jump identified from current low point @ index {current_low_point}..  moving to next low point")
            if current_low_point + 2 < len(extreme_points):
                current_low_point = current_low_point + 2
                current_low_point_index = extreme_points[current_low_point][0]
                current_low_point_value = extreme_points[current_low_point][1]
            else:
                current_low_point = None
                break

    return (current_low_point, NextHighPoint)

# %%
start_point = 2  # Starting from the first low point in the given example
price_jump = 30  # Looking for a 5% price jump
print(f"low_point_index :: {start_point}")

next_low_point, probable_high_point = NextLowPoint(start_point, extreme_points, price_jump)
print(f"next_low_point >> {next_low_point}... probable_high_point>> {probable_high_point}")
if next_low_point is not None:
    low_point_index = extreme_points[next_low_point][0]
if probable_high_point is not None:
    probable_high_point_index = extreme_points[probable_high_point][0]
else:
    probable_high_point_index = None
print(f"Next Low Point Index: {next_low_point}, Next High Point Index: {probable_high_point}")
if next_low_point is not None:
    print(f"start_date is {get_candle_date(df_last_3_months, low_point_index)}.. end_date is {get_candle_date(df_last_3_months, probable_high_point_index)}")
# Out:
# low_point_index :: 2
# supertrend called from low_point 4049 and high_point is 4155
# Initial noise period index: 4065.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 33.57105366535587, 'time_taken': 106, 'slope': 0.31670805344675346, 'desc': 'Moving average check is FAILED and time_taken is 106', 'max_1D_decline': -7.644439697265624, 'max_5D_decline': -8.525251908735795}
# supertrend called from low_point 4049 and high_point is 4163
# Initial noise period index: 4067.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 28.57897505671565, 'time_taken': 114, 'slope': 0.25069276365540044, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 114', 'max_1D_decline': -7.644439697265624, 'max_5D_decline': -8.525251908735795}
# supertrend called from low_point 4049 and high_point is 4275
# Initial noise period index: 4083.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 57.950343159534256, 'time_taken': 226, 'slope': 0.25641744760855867, 'desc': 'Moving average check is FAILED and time_taken is 226', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# supertrend called from low_point 4049 and high_point is 4308
# Initial noise period index: 4088.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 61.91230839004898, 'time_taken': 259, 'slope': 0.23904366173764083, 'desc': 'Moving average check is FAILED and time_taken is 259', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 3..  moving to next low point
# supertrend called from low_point 4161 and high_point is 4163
# Initial noise period index: 4162.
# output_json : {'superUpTrend': False, 'price_jump': 8.733521223996837, 'time_taken': 2, 'slope': 4.366760611998418, 'desc': 'Price jump < 30%. Time taken 2 not in range 10 & None. High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.0 < 1.25. ', 'max_1D_decline': -7.116182980480179, 'max_5D_decline': -5.148299432149965}
# supertrend called from low_point 4161 and high_point is 4275
# Initial noise period index: 4179.
# output_json : {'superUpTrend': True, 'price_jump': 33.57158106680507, 'time_taken': 114, 'slope': 0.2944875532175883, 'desc': '', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# next_low_point >> 5... probable_high_point>> 8
# Next Low Point Index: 5, Next High Point Index: 8
# start_date is 2012-05-08 00:00:00.. end_date is 2012-10-19 00:00:00

# %% [markdown]
# **NextHighPoint**

# %%
def NextHighPoint(low_point, Next_High_Point, extreme_points, df, price_jump, max_time_taken = 250, stage2_potential_df=None, correction_factor = 40, stock_name = None):
    """
    Identify the next high point for a given low point and confirm if it's a super uptrend.
    """

    current_high_point = Next_High_Point
    # Retrieve the index for the low_point and Probable_High_Point within extreme_points
    low_point_index = extreme_points[low_point][0]

    current_high_point_index = extreme_points[current_high_point][0]
    final_high_point = None

    if Next_High_Point is None:
        Next_High_Point = low_point + 1

    if Next_High_Point <= low_point:
        print("Incorrect Probable_High_Point provided to NextHighPoint function..  it can't be lesser than low_point")
        return (None, None)

    while current_high_point + 1 < len(extreme_points):

        # Check for super uptrend between the current low and new high point
        # print("Trying to confirm super UpTrend")
        # print(f"start_index is {low_point_index}... and end_index is {current_high_point_index} ")
        result = superUpTrend(
            start_index=low_point_index,
            end_index=current_high_point_index,
            df=df,
            min_jump=price_jump,
            min_time=10,
            max_time=None,
            min_slope=0.1,
            comparison_type='HIGH-LOW',
            TimeLookBack=500,  # Example: look back 500 candles from end_index to check if stock is in new territory
            priceVolumeThreshold=1.25
        )
        max_time_exceeded = False
        if result["superUpTrend"]:
              print("Super uptrend confirmed.")
              # Apppend the record to new DataFrame
              # Create a new DataFrame for the row you want to append
              new_row_df = pd.DataFrame([{
                  'Stock_name': stock_name,  # This should be dynamic based on your data
                  'Start_Index': low_point_index,
                  'End_Index': current_high_point_index,
                  'Price_Percentage_Change': result["price_jump"],
                  'Slope': result["slope"],
                  'Change_Time_Taken': result["time_taken"],
                  'Start_date': get_candle_date(df,low_point_index ),  # This should be derived from your data
                  'End_Date': get_candle_date(df,current_high_point_index ),  # This should be derived from your data
                  'max_1D_decline': result["max_1D_decline"],
                  'max_5D_decline': result["max_5D_decline"],
                  'current_high_point': current_high_point
              }], columns=stage2_potential_df.columns)
              print(f"New record inserted {new_row_df}")
              stage2_potential_df = pd.concat([stage2_potential_df, new_row_df], ignore_index=True)
              final_high_point = current_high_point
        else:
              print(f"result[time_taken] is ", result["time_taken"])
              if result["time_taken"] > max_time_taken:
                  print("Exceeded the max_time_taken hence giving up the next_high_point search")
                  max_time_exceeded = True
                  break
        if max_time_exceeded:
            break

        found_higher_high = False
        found_low_correction = False
        found_significant_side_move = False

        for i in range(current_high_point + 1, len(extreme_points)):
            point_index, point_value, point_type = extreme_points[i]

            if point_type == "LOW" :
                # Ensure that there has not been a significant decline.  If there is more than say 40% correction in upmove it can be significant decline
                if point_value < (extreme_points[current_high_point][1] - extreme_points[low_point][1]) * correction_factor /100 + extreme_points[low_point][1]:
                    found_higher_high = False
                    found_low_correction = True
                    # print(f"After a new high point @{extreme_points[current_high_point][0]}, correction happened>>>")
                if final_high_point is not None:
                    upMoveTimeTaken = extreme_points[current_high_point][0] - extreme_points[low_point][0]
                    sideWaysTimeTaken = extreme_points[i][0] - extreme_points[final_high_point][0]
                    # Ensure that there has not been a significant SIDE WAY MOVE.  If there is more time taken than total up_move then that's the case.
                    if sideWaysTimeTaken > upMoveTimeTaken:
                        found_significant_side_move = True

            if point_type == "HIGH" and point_value > extreme_points[current_high_point][1]:
                # print(f"Found new HIGH point at index {i} with value {point_value}")
                # Update current high point and continue the search
                current_high_point = i
                current_high_point_index = extreme_points[current_high_point][0]
                found_higher_high = True
                break

        if not found_higher_high:
            # print("No further 'HIGH' points found that exceed the current high point.")
            break

        if found_low_correction:
            print('Significant correction found hence skipping the next_high_point search instead new_low_point to be found')
            break

        if found_significant_side_move:
            print('Significant side way move found hence skipping the next_high_point search, instead new_low_point to be found')
            break


    return final_high_point, stage2_potential_df

# %%
# Placeholder setup for demonstration
low_point = 0  # Assuming this is the index of the low point in your extreme_points
Probable_High_Point = 3  # Assuming this is the index of a high point in your extreme_points
price_jump = 10  # Example price jump percentage criterion

low_point_index = get_index('2023-11-01',df_last_3_months)
low_point_index = 6092
for position, (index, _, _) in enumerate(extreme_points):
    if index == low_point_index:
        low_point =  position
print(f"low_point_index = {low_point_index}")
print(f"low_point = {low_point}")

Probable_High_Point = low_point + 1

# Initialize stage2_potential_df if not already present
stage2_potential_df = pd.DataFrame(columns=['Stock_name', 'Start_Index', 'End_Index',
                                                'Price_Percentage_Change', 'Slope', 'Change_Time_Taken',
                                                'Start_date', 'End_Date', 'max_1D_decline', 'max_5D_decline', 'current_high_point' ])

# Call the NextHighPoint function
current_high_point_index, updated_stage2_potential_df = NextHighPoint(
    low_point,
    Probable_High_Point,
    extreme_points,
    df=df_last_3_months,
    price_jump = 1,
    stage2_potential_df = stage2_potential_df,
    correction_factor = 40,
    stock_name='ITC'
)

# Example output
print("Updated stage2_potential_df:")
print(updated_stage2_potential_df)

# Note: This example assumes the NextHighPoint function, and the superUpTrend function have been correctly
# defined and integrated as per earlier discussions. The superUpTrend function needs to be compatible
# with the parameters passed from NextHighPoint and should return a JSON object with super uptrend analysis results.
# Out:
# low_point_index = 6092
# low_point = 77
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6097
# output_json : {'superUpTrend': False, 'price_jump': 31.12926597065733, 'time_taken': 5, 'slope': 6.225853194131465, 'desc': 'Time taken 5 not in range 10 & None. Moving average check is FAILED and time_taken is 5', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -17.70538243626062}
# result[time_taken] is  5
# Significant correction found hence skipping the next_high_point search instead new_low_point to be found
# Updated stage2_potential_df:
# Empty DataFrame
# Columns: [Stock_name, Start_Index, End_Index, Price_Percentage_Change, Slope, Change_Time_Taken, Start_date, End_Date, max_1D_decline, max_5D_decline, current_high_point]
# Index: []
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Stage2 Identifier**

# %%
import pandas as pd

def Stage2Identifier(stock_name, extreme_points, price_jump, df):
    """
    Identifies potential VCP stage 2 moves within the entire stock data series.

    Parameters:
    - stock_name: Name of the stock being analyzed.
    - extreme_points: Array of tuples containing extreme points (index, value, type).
    - price_jump: The minimum price jump percentage required to consider a move significant.
    - df: DataFrame containing OHLC data for the stock.

    Returns:
    - DataFrame containing identified stage 2 potential moves.
    """
    # Initialize the DataFrame to store potential stage 2 moves
    stage2_potential_df = pd.DataFrame(columns=['Stock_name', 'Start_Index', 'End_Index',
                                                'Price_Percentage_Change', 'Slope', 'Change_Time_Taken',
                                                'Start_date', 'End_Date', 'max_1D_decline', 'max_5D_decline', 'current_high_point'])
    start_point = 0

    print(f"Starting Stage2Identifier for stock: {stock_name} with price jump criterion: {price_jump}%")

    while start_point < len(extreme_points) - 1:
        print(f"Analyzing from start point: {start_point} in extreme points.")
        current_low_point, Next_High_Point = NextLowPoint(start_point, extreme_points, price_jump)
        if current_low_point is not None and Next_High_Point is not None:
            print(f"current_low_point index is {extreme_points[current_low_point][0]} and date is  {get_candle_date(df, extreme_points[current_low_point][0])} ")

        if Next_High_Point is None and current_low_point is None and start_point < len(extreme_points) - 1:
            print(f"start_point is {start_point} and extreme_points length is {len(extreme_points)}")
            print("No low point to high point left to be evaluated. Ending analysis.")
            break
        else:
            print(f"Next high point found at {extreme_points[Next_High_Point][0]}. LOW Point at {extreme_points[current_low_point][0]} Attempting to identify a stage 2 move.")
            current_high_point, stage2_potential_df = NextHighPoint(
                low_point=current_low_point,
                Next_High_Point=Next_High_Point,
                extreme_points=extreme_points,
                df=df,
                price_jump=price_jump,
                stage2_potential_df=stage2_potential_df,
                correction_factor = 40,
                stock_name=stock_name
            )


            if current_high_point is None:
                print("No new high point identified. Exiting the loop.")
                break
            else:
                print(f"New high point identified at {current_high_point}. Moving to the next analysis point.")
                # Assuming NextHighPoint returns the index in extreme_points, find the next start point
                start_point =  current_high_point + 1

    print("Stage 2 identification complete.")
    return stage2_potential_df

# %%
# Call the Stage2PotentialIdentifier function for stock "ITC" with a price jump criterion of 10%
stage2_potential_df = Stage2Identifier(
    stock_name="ITC",
    extreme_points=filtered_extreme_points,
    price_jump=30,
    df=df_last_3_months
)

# Display the identified potential stage 2 moves
print("Identified Stage 2 Potential Moves:")
print(stage2_potential_df)
# Out:
# Starting Stage2Identifier for stock: ITC with price jump criterion: 30%
# Analyzing from start point: 0 in extreme points.
# supertrend called from low_point 4012 and high_point is 4033
# Initial noise period index: 4016.
# output_json : {'superUpTrend': False, 'price_jump': 16.864860805514343, 'time_taken': 21, 'slope': 0.8030886097863973, 'desc': 'Price jump < 30%. ', 'max_1D_decline': -5.025870582690624, 'max_5D_decline': -8.415843154762074}
# supertrend called from low_point 4012 and high_point is 4155
# Initial noise period index: 4034.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 36.675672032625926, 'time_taken': 143, 'slope': 0.2564732309973841, 'desc': 'Moving average check is FAILED and time_taken is 143', 'max_1D_decline': -7.644439697265624, 'max_5D_decline': -8.525251908735795}
# supertrend called from low_point 4012 and high_point is 4308
# Initial noise period index: 4057.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 65.6756681354488, 'time_taken': 296, 'slope': 0.22187725721435406, 'desc': 'Moving average check is FAILED and time_taken is 296', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 1..  moving to next low point
# supertrend called from low_point 4049 and high_point is 4155
# Initial noise period index: 4065.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 33.57105366535587, 'time_taken': 106, 'slope': 0.31670805344675346, 'desc': 'Moving average check is FAILED and time_taken is 106', 'max_1D_decline': -7.644439697265624, 'max_5D_decline': -8.525251908735795}
# supertrend called from low_point 4049 and high_point is 4308
# Initial noise period index: 4088.
# Check 2 failed: MA order incorrect at index 4095.
# output_json : {'superUpTrend': False, 'price_jump': 61.91230839004898, 'time_taken': 259, 'slope': 0.23904366173764083, 'desc': 'Moving average check is FAILED and time_taken is 259', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 3..  moving to next low point
# supertrend called from low_point 4161 and high_point is 4308
# Initial noise period index: 4184.
# output_json : {'superUpTrend': True, 'price_jump': 36.922038871363604, 'time_taken': 147, 'slope': 0.2511703324582558, 'desc': '', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# current_low_point index is 4161 and date is  2012-05-08 00:00:00
# Next high point found at 4308. LOW Point at 4161 Attempting to identify a stage 2 move.
# Initial noise period index: 4184.
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3586312494.py:56: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# output_json : {'superUpTrend': True, 'price_jump': 36.922038871363604, 'time_taken': 147, 'slope': 0.2511703324582558, 'desc': '', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Super uptrend confirmed.
# New record inserted   Stock_name  Start_Index  End_Index  Price_Percentage_Change    Slope  \
# 0        ITC         4161       4308                36.922039  0.25117
#
#    Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0                147 2012-05-08 2012-12-12      -21.170366      -22.624276
#
#    current_high_point
# 0                   6
# Initial noise period index: 4199.
# output_json : {'superUpTrend': True, 'price_jump': 58.2086216211684, 'time_taken': 248, 'slope': 0.23471218395632418, 'desc': '', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Super uptrend confirmed.
# New record inserted   Stock_name  Start_Index  End_Index  Price_Percentage_Change     Slope  \
# 0        ITC         4161       4409                58.208622  0.234712
#
#    Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0                248 2012-05-08 2013-05-10      -21.170366      -22.624276
#
#    current_high_point
# 0                   8
# Initial noise period index: 4207.
# output_json : {'superUpTrend': True, 'price_jump': 69.75652535603727, 'time_taken': 301, 'slope': 0.23174925367454244, 'desc': '', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# Super uptrend confirmed.
# New record inserted   Stock_name  Start_Index  End_Index  Price_Percentage_Change     Slope  \
# 0        ITC         4161       4462                69.756525  0.231749
#
#    Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0                301 2012-05-08 2013-07-24      -21.170366      -22.624276
#
#    current_high_point
# 0                  10
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4161 & end_index @4660
# output_json : {'superUpTrend': False, 'price_jump': 73.10699338538159, 'time_taken': 499, 'slope': 0.1465070007723078, 'desc': 'Moving average check is FAILED and time_taken is 499', 'max_1D_decline': -21.17036607659825, 'max_5D_decline': -22.624276447129862}
# result[time_taken] is  499
# Exceeded the max_time_taken hence giving up the next_high_point search
# New high point identified at 10. Moving to the next analysis point.
# Analyzing from start point: 11 in extreme points.
# supertrend called from low_point 4481 and high_point is 4501
# Initial noise period index: 4484.
# output_json : {'superUpTrend': False, 'price_jump': 23.44828174060379, 'time_taken': 20, 'slope': 1.1724140870301896, 'desc': 'Price jump < 30%. ', 'max_1D_decline': -8.303784084894044, 'max_5D_decline': -12.878338440160148}
# supertrend called from low_point 4481 and high_point is 4660
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4481 & end_index @4660
# output_json : {'superUpTrend': False, 'price_jump': 33.62069843215149, 'time_taken': 179, 'slope': 0.18782513090587427, 'desc': 'Moving average check is FAILED and time_taken is 179', 'max_1D_decline': -8.303784084894044, 'max_5D_decline': -12.878338440160148}
# supertrend called from low_point 4481 and high_point is 4800
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4481 & end_index @4800
# output_json : {'superUpTrend': False, 'price_jump': 38.03448744239774, 'time_taken': 319, 'slope': 0.11923036815798664, 'desc': 'Moving average check is FAILED and time_taken is 319High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.2115384615384615 < 1.25. ', 'max_1D_decline': -8.303784084894044, 'max_5D_decline': -12.878338440160148}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 11..  moving to next low point
# supertrend called from low_point 4551 and high_point is 4660
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4551 & end_index @4660
# output_json : {'superUpTrend': False, 'price_jump': 25.99577363062542, 'time_taken': 109, 'slope': 0.23849333606078366, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 109', 'max_1D_decline': -6.025811727184203, 'max_5D_decline': -10.96774544135327}
# supertrend called from low_point 4551 and high_point is 4800
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4551 & end_index @4800
# output_json : {'superUpTrend': False, 'price_jump': 30.157694407223584, 'time_taken': 249, 'slope': 0.12111523858322724, 'desc': 'Moving average check is FAILED and time_taken is 249High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.2439024390243902 < 1.25. ', 'max_1D_decline': -7.005208730697621, 'max_5D_decline': -10.96774544135327}
# supertrend called from low_point 4551 and high_point is 4845
# Check 1 failed: 200-day MA not increasing at index 4600. start_index @4551 & end_index @4845
# output_json : {'superUpTrend': False, 'price_jump': 30.71044904523419, 'time_taken': 294, 'slope': 0.10445730967766731, 'desc': 'Moving average check is FAILED and time_taken is 294High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.2156862745098038 < 1.25. ', 'max_1D_decline': -7.005208730697621, 'max_5D_decline': -10.96774544135327}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 13..  moving to next low point
# supertrend called from low_point 4686 and high_point is 4800
# Check 1 failed: 200-day MA not increasing at index 4688. start_index @4686 & end_index @4800
# output_json : {'superUpTrend': False, 'price_jump': 28.096004103906353, 'time_taken': 114, 'slope': 0.24645617635005573, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 114High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.0 < 1.25. ', 'max_1D_decline': -7.005208730697621, 'max_5D_decline': -10.724996975898616}
# supertrend called from low_point 4686 and high_point is 4845
# Check 1 failed: 200-day MA not increasing at index 4688. start_index @4686 & end_index @4845
# output_json : {'superUpTrend': False, 'price_jump': 28.640003140625076, 'time_taken': 159, 'slope': 0.18012580591588098, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 159High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.0333333333333334 < 1.25. ', 'max_1D_decline': -7.005208730697621, 'max_5D_decline': -10.724996975898616}
# supertrend called from low_point 4686 and high_point is 4881
# Check 1 failed: 200-day MA not increasing at index 4688. start_index @4686 & end_index @4881
# output_json : {'superUpTrend': False, 'price_jump': 14.75200231328132, 'time_taken': 195, 'slope': 0.07565129391426317, 'desc': 'Price jump < 30%. Slope < 0.1. Moving average check is FAILED and time_taken is 195High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.0833333333333333 < 1.25. ', 'max_1D_decline': -7.005208730697621, 'max_5D_decline': -10.724996975898616}
# supertrend called from low_point 4923 and high_point is 5014
# Check 1 failed: 200-day MA not increasing at index 4924. start_index @4923 & end_index @5014
# output_json : {'superUpTrend': False, 'price_jump': 22.380953418965245, 'time_taken': 91, 'slope': 0.24594454306555213, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 91', 'max_1D_decline': -8.36896591548122, 'max_5D_decline': -9.923437808501689}
# supertrend called from low_point 5099 and high_point is 5226
# Check 1 failed: 200-day MA not increasing at index 5100. start_index @5099 & end_index @5226
# output_json : {'superUpTrend': False, 'price_jump': 48.82461921280194, 'time_taken': 127, 'slope': 0.3844458205732436, 'desc': 'Moving average check is FAILED and time_taken is 127', 'max_1D_decline': -18.042811122509317, 'max_5D_decline': -16.705514334298513}
# supertrend called from low_point 5099 and high_point is 5266
# Check 1 failed: 200-day MA not increasing at index 5100. start_index @5099 & end_index @5266
# output_json : {'superUpTrend': False, 'price_jump': 45.326484984028234, 'time_taken': 167, 'slope': 0.27141607774867205, 'desc': 'Moving average check is FAILED and time_taken is 167', 'max_1D_decline': -18.042811122509317, 'max_5D_decline': -16.705514334298513}
# supertrend called from low_point 5099 and high_point is 5330
# Check 1 failed: 200-day MA not increasing at index 5100. start_index @5099 & end_index @5330
# output_json : {'superUpTrend': False, 'price_jump': 63.51678297365152, 'time_taken': 231, 'slope': 0.2749644284573659, 'desc': 'Moving average check is FAILED and time_taken is 231', 'max_1D_decline': -18.042811122509317, 'max_5D_decline': -16.705514334298513}
# supertrend called from low_point 5099 and high_point is 5428
# Check 1 failed: 200-day MA not increasing at index 5100. start_index @5099 & end_index @5428
# output_json : {'superUpTrend': False, 'price_jump': 98.58207706673247, 'time_taken': 329, 'slope': 0.2996415716314057, 'desc': 'Moving average check is FAILED and time_taken is 329', 'max_1D_decline': -18.042811122509317, 'max_5D_decline': -16.705514334298513}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 23..  moving to next low point
# supertrend called from low_point 5259 and high_point is 5266
# Initial noise period index: 5261.
# output_json : {'superUpTrend': False, 'price_jump': 11.199140855025428, 'time_taken': 7, 'slope': 1.5998772650036326, 'desc': 'Price jump < 30%. Time taken 7 not in range 10 & None. ', 'max_1D_decline': -7.95631606166122, 'max_5D_decline': -8.663554126554063}
# supertrend called from low_point 5300 and high_point is 5330
# Initial noise period index: 5305.
# Check 2 failed: MA order incorrect at index 5305.
# output_json : {'superUpTrend': False, 'price_jump': 31.599096349767734, 'time_taken': 30, 'slope': 1.0533032116589245, 'desc': 'Moving average check is FAILED and time_taken is 30', 'max_1D_decline': -7.64558569601068, 'max_5D_decline': -11.518053944716959}
# supertrend called from low_point 5300 and high_point is 5428
# Initial noise period index: 5320.
# Check 2 failed: MA order incorrect at index 5320.
# output_json : {'superUpTrend': False, 'price_jump': 59.8198143211571, 'time_taken': 128, 'slope': 0.4673422993840398, 'desc': 'Moving average check is FAILED and time_taken is 128', 'max_1D_decline': -12.556366777262786, 'max_5D_decline': -12.344980073259393}
# supertrend called from low_point 5300 and high_point is 5575
# Check 1 failed: 200-day MA not increasing at index 5520. start_index @5300 & end_index @5575
# output_json : {'superUpTrend': False, 'price_jump': 30.765760267103044, 'time_taken': 275, 'slope': 0.11187549188037471, 'desc': 'Moving average check is FAILED and time_taken is 275', 'max_1D_decline': -12.556366777262786, 'max_5D_decline': -12.344980073259393}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 27..  moving to next low point
# supertrend called from low_point 5343 and high_point is 5428
# Initial noise period index: 5356.
# output_json : {'superUpTrend': True, 'price_jump': 37.59937149294924, 'time_taken': 85, 'slope': 0.4423455469758734, 'desc': '', 'max_1D_decline': -12.556366777262786, 'max_5D_decline': -12.344980073259393}
# current_low_point index is 5343 and date is  2017-02-27 00:00:00
# Next high point found at 5428. LOW Point at 5343 Attempting to identify a stage 2 move.
# Initial noise period index: 5356.
# output_json : {'superUpTrend': True, 'price_jump': 37.59937149294924, 'time_taken': 85, 'slope': 0.4423455469758734, 'desc': '', 'max_1D_decline': -12.556366777262786, 'max_5D_decline': -12.344980073259393}
# Super uptrend confirmed.
# New record inserted   Stock_name  Start_Index  End_Index  Price_Percentage_Change     Slope  \
# 0        ITC         5343       5428                37.599371  0.442346
#
#    Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0                 85 2017-02-27 2017-07-03      -12.556367       -12.34498
#
#    current_high_point
# 0                  30
# Significant correction found hence skipping the next_high_point search instead new_low_point to be found
# New high point identified at 30. Moving to the next analysis point.
# Analyzing from start point: 31 in extreme points.
# supertrend called from low_point 5537 and high_point is 5575
# Check 1 failed: 200-day MA not increasing at index 5538. start_index @5537 & end_index @5575
# output_json : {'superUpTrend': False, 'price_jump': 16.1199951171875, 'time_taken': 38, 'slope': 0.4242103978207237, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 38', 'max_1D_decline': -7.04443077828763, 'max_5D_decline': -6.3841342496055}
# supertrend called from low_point 5537 and high_point is 5635
# Check 1 failed: 200-day MA not increasing at index 5538. start_index @5537 & end_index @5635
# output_json : {'superUpTrend': False, 'price_jump': 15.880004882812502, 'time_taken': 98, 'slope': 0.162040866151148, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 98', 'max_1D_decline': -7.04443077828763, 'max_5D_decline': -7.142857142857142}
# supertrend called from low_point 5537 and high_point is 5720
# Check 1 failed: 200-day MA not increasing at index 5538. start_index @5537 & end_index @5720
# output_json : {'superUpTrend': False, 'price_jump': 29.1800048828125, 'time_taken': 183, 'slope': 0.15945357859460382, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 183', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# supertrend called from low_point 5537 and high_point is 5869
# Check 1 failed: 200-day MA not increasing at index 5538. start_index @5537 & end_index @5869
# output_json : {'superUpTrend': False, 'price_jump': 24.0, 'time_taken': 332, 'slope': 0.07228915662650602, 'desc': 'Price jump < 30%. Slope < 0.1. Moving average check is FAILED and time_taken is 332', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 31..  moving to next low point
# supertrend called from low_point 5597 and high_point is 5635
# Check 1 failed: 200-day MA not increasing at index 5598. start_index @5597 & end_index @5635
# output_json : {'superUpTrend': False, 'price_jump': 14.257546330178528, 'time_taken': 38, 'slope': 0.37519858763627706, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 38', 'max_1D_decline': -5.808527086402827, 'max_5D_decline': -7.142857142857142}
# supertrend called from low_point 5597 and high_point is 5720
# Check 1 failed: 200-day MA not increasing at index 5598. start_index @5597 & end_index @5720
# output_json : {'superUpTrend': False, 'price_jump': 27.371330435798352, 'time_taken': 123, 'slope': 0.22253114175445815, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 123', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# supertrend called from low_point 5597 and high_point is 5869
# Check 1 failed: 200-day MA not increasing at index 5598. start_index @5597 & end_index @5869
# output_json : {'superUpTrend': False, 'price_jump': 22.263851811793867, 'time_taken': 272, 'slope': 0.08185239636688922, 'desc': 'Price jump < 30%. Slope < 0.1. Moving average check is FAILED and time_taken is 272', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 33..  moving to next low point
# supertrend called from low_point 5675 and high_point is 5720
# Check 1 failed: 200-day MA not increasing at index 5676. start_index @5675 & end_index @5720
# output_json : {'superUpTrend': False, 'price_jump': 24.69112440425917, 'time_taken': 45, 'slope': 0.5486916534279815, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 45', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# supertrend called from low_point 5675 and high_point is 5869
# Check 1 failed: 200-day MA not increasing at index 5676. start_index @5675 & end_index @5869
# output_json : {'superUpTrend': False, 'price_jump': 19.69111969111969, 'time_taken': 194, 'slope': 0.1015006169645345, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 194', 'max_1D_decline': -7.471913444734667, 'max_5D_decline': -9.767214910025555}
# supertrend called from low_point 5972 and high_point is 6005
# Check 1 failed: 200-day MA not increasing at index 5973. start_index @5972 & end_index @6005
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# output_json : {'superUpTrend': False, 'price_jump': 13.77910032929125, 'time_taken': 33, 'slope': 0.41754849482700757, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 33', 'max_1D_decline': -10.057580402396233, 'max_5D_decline': -9.282944553582244}
# supertrend called from low_point 6092 and high_point is 6097
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6097
# output_json : {'superUpTrend': False, 'price_jump': 31.12926597065733, 'time_taken': 5, 'slope': 6.225853194131465, 'desc': 'Time taken 5 not in range 10 & None. Moving average check is FAILED and time_taken is 5', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -17.70538243626062}
# supertrend called from low_point 6092 and high_point is 6111
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6111
# output_json : {'superUpTrend': False, 'price_jump': 43.94501576099069, 'time_taken': 19, 'slope': 2.3128955663679314, 'desc': 'Moving average check is FAILED and time_taken is 19', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6092 and high_point is 6148
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6148
# output_json : {'superUpTrend': False, 'price_jump': 53.19464160325654, 'time_taken': 56, 'slope': 0.9499043143438668, 'desc': 'Moving average check is FAILED and time_taken is 56', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6092 and high_point is 6161
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6161
# output_json : {'superUpTrend': False, 'price_jump': 55.572053789836396, 'time_taken': 69, 'slope': 0.8053920839106724, 'desc': 'Moving average check is FAILED and time_taken is 69', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6092 and high_point is 6319
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6319
# output_json : {'superUpTrend': False, 'price_jump': 77.71172815867689, 'time_taken': 227, 'slope': 0.3423424147959334, 'desc': 'Moving average check is FAILED and time_taken is 227', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6092 and high_point is 6348
# Check 1 failed: 200-day MA not increasing at index 6093. start_index @6092 & end_index @6348
# output_json : {'superUpTrend': False, 'price_jump': 69.46507857369097, 'time_taken': 256, 'slope': 0.27134796317848037, 'desc': 'Moving average check is FAILED and time_taken is 256', 'max_1D_decline': -17.988668555240793, 'max_5D_decline': -20.04601948806655}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 41..  moving to next low point
# supertrend called from low_point 6100 and high_point is 6111
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6111
# output_json : {'superUpTrend': False, 'price_jump': 39.38848920863309, 'time_taken': 11, 'slope': 3.5807717462393716, 'desc': 'Moving average check is FAILED and time_taken is 11', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6100 and high_point is 6148
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6148
# output_json : {'superUpTrend': False, 'price_jump': 48.345321545497974, 'time_taken': 48, 'slope': 1.0071941988645412, 'desc': 'Moving average check is FAILED and time_taken is 48', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6100 and high_point is 6161
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6161
# output_json : {'superUpTrend': False, 'price_jump': 50.64747762337007, 'time_taken': 61, 'slope': 0.8302865184159028, 'desc': 'Moving average check is FAILED and time_taken is 61', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6100 and high_point is 6319
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6319
# output_json : {'superUpTrend': False, 'price_jump': 72.08632873974258, 'time_taken': 219, 'slope': 0.3291613184463132, 'desc': 'Moving average check is FAILED and time_taken is 219', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6100 and high_point is 6348
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6348
# output_json : {'superUpTrend': False, 'price_jump': 64.10072381547884, 'time_taken': 248, 'slope': 0.25847066054628565, 'desc': 'Moving average check is FAILED and time_taken is 248High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.2307692307692308 < 1.25. ', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# supertrend called from low_point 6100 and high_point is 6488
# Check 1 failed: 200-day MA not increasing at index 6101. start_index @6100 & end_index @6488
# output_json : {'superUpTrend': False, 'price_jump': 90.86330057048112, 'time_taken': 388, 'slope': 0.2341837643569101, 'desc': 'Moving average check is FAILED and time_taken is 388', 'max_1D_decline': -13.704819277108435, 'max_5D_decline': -20.04601948806655}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 43..  moving to next low point
# supertrend called from low_point 6127 and high_point is 6148
# Check 1 failed: 200-day MA not increasing at index 6128. start_index @6127 & end_index @6148
# output_json : {'superUpTrend': False, 'price_jump': 31.253971315808748, 'time_taken': 21, 'slope': 1.488284348371845, 'desc': 'Moving average check is FAILED and time_taken is 21', 'max_1D_decline': -10.212652801211666, 'max_5D_decline': -15.384617233530623}
# supertrend called from low_point 6127 and high_point is 6161
# Check 1 failed: 200-day MA not increasing at index 6128. start_index @6127 & end_index @6161
# output_json : {'superUpTrend': False, 'price_jump': 33.29088845388555, 'time_taken': 34, 'slope': 0.9791437780554574, 'desc': 'Moving average check is FAILED and time_taken is 34', 'max_1D_decline': -10.212652801211666, 'max_5D_decline': -15.384617233530623}
# supertrend called from low_point 6127 and high_point is 6319
# Check 1 failed: 200-day MA not increasing at index 6128. start_index @6127 & end_index @6319
# output_json : {'superUpTrend': False, 'price_jump': 52.25969933484892, 'time_taken': 192, 'slope': 0.27218593403567143, 'desc': 'Moving average check is FAILED and time_taken is 192', 'max_1D_decline': -10.212652801211666, 'max_5D_decline': -15.511828388105892}
# supertrend called from low_point 6127 and high_point is 6348
# Check 1 failed: 200-day MA not increasing at index 6128. start_index @6127 & end_index @6348
# output_json : {'superUpTrend': False, 'price_jump': 45.19414210157126, 'time_taken': 221, 'slope': 0.2044983805500962, 'desc': 'Moving average check is FAILED and time_taken is 221', 'max_1D_decline': -10.212652801211666, 'max_5D_decline': -15.511828388105892}
# supertrend called from low_point 6127 and high_point is 6488
# Check 1 failed: 200-day MA not increasing at index 6128. start_index @6127 & end_index @6488
# output_json : {'superUpTrend': False, 'price_jump': 68.87331475859936, 'time_taken': 361, 'slope': 0.190784805425483, 'desc': 'Moving average check is FAILED and time_taken is 361', 'max_1D_decline': -10.212652801211666, 'max_5D_decline': -15.511828388105892}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 45..  moving to next low point
# supertrend called from low_point 6154 and high_point is 6161
# Check 1 failed: 200-day MA not increasing at index 6155. start_index @6154 & end_index @6161
# output_json : {'superUpTrend': False, 'price_jump': 15.88267705198841, 'time_taken': 7, 'slope': 2.268953864569773, 'desc': 'Price jump < 30%. Time taken 7 not in range 10 & None. Moving average check is FAILED and time_taken is 7', 'max_1D_decline': -8.52580152506909, 'max_5D_decline': -12.535816984300643}
# supertrend called from low_point 6250 and high_point is 6319
# Check 1 failed: 200-day MA not increasing at index 6251. start_index @6250 & end_index @6319
# output_json : {'superUpTrend': False, 'price_jump': 46.43403000343941, 'time_taken': 69, 'slope': 0.6729569565715856, 'desc': 'Moving average check is FAILED and time_taken is 69', 'max_1D_decline': -9.709170894068093, 'max_5D_decline': -15.511828388105892}
# supertrend called from low_point 6250 and high_point is 6348
# Check 1 failed: 200-day MA not increasing at index 6251. start_index @6250 & end_index @6348
# output_json : {'superUpTrend': False, 'price_jump': 39.63881088499477, 'time_taken': 98, 'slope': 0.4044776620917834, 'desc': 'Moving average check is FAILED and time_taken is 98', 'max_1D_decline': -9.709170894068093, 'max_5D_decline': -15.511828388105892}
# supertrend called from low_point 6250 and high_point is 6488
# Check 1 failed: 200-day MA not increasing at index 6251. start_index @6250 & end_index @6488
# output_json : {'superUpTrend': False, 'price_jump': 62.41198523423805, 'time_taken': 238, 'slope': 0.26223523207663046, 'desc': 'Moving average check is FAILED and time_taken is 238', 'max_1D_decline': -9.709170894068093, 'max_5D_decline': -15.511828388105892}
# supertrend called from low_point 6250 and high_point is 6509
# Check 1 failed: 200-day MA not increasing at index 6251. start_index @6250 & end_index @6509
# output_json : {'superUpTrend': False, 'price_jump': 50.137735436987974, 'time_taken': 259, 'slope': 0.19358199010420069, 'desc': 'Moving average check is FAILED and time_taken is 259', 'max_1D_decline': -9.709170894068093, 'max_5D_decline': -15.511828388105892}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 49..  moving to next low point
# supertrend called from low_point 6342 and high_point is 6348
# Initial noise period index: 6343.
# output_json : {'superUpTrend': False, 'price_jump': 13.144840871876283, 'time_taken': 6, 'slope': 2.1908068119793804, 'desc': 'Price jump < 30%. Time taken 6 not in range 10 & None. ', 'max_1D_decline': -6.3011277402566055, 'max_5D_decline': -10.855621691595564}
# supertrend called from low_point 6374 and high_point is 6488
# Initial noise period index: 6392.
# Check 2 failed: MA order incorrect at index 6405.
# output_json : {'superUpTrend': False, 'price_jump': 33.249613088929095, 'time_taken': 114, 'slope': 0.29166327270990433, 'desc': 'Moving average check is FAILED and time_taken is 114', 'max_1D_decline': -8.849557408315608, 'max_5D_decline': -12.664904783541441}
# supertrend called from low_point 6374 and high_point is 6509
# Initial noise period index: 6395.
# Check 2 failed: MA order incorrect at index 6405.
# output_json : {'superUpTrend': False, 'price_jump': 23.179303104837782, 'time_taken': 135, 'slope': 0.1716985415173169, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 135', 'max_1D_decline': -8.849557408315608, 'max_5D_decline': -12.664904783541441}
# supertrend called from low_point 6374 and high_point is 6564
# Check 1 failed: 200-day MA not increasing at index 6516. start_index @6374 & end_index @6564
# output_json : {'superUpTrend': False, 'price_jump': 19.789047056080776, 'time_taken': 190, 'slope': 0.1041528792425304, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 190High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.2 < 1.25. ', 'max_1D_decline': -8.849557408315608, 'max_5D_decline': -12.664904783541441}
# supertrend called from low_point 6374 and high_point is 6926
# Check 1 failed: 200-day MA not increasing at index 6516. start_index @6374 & end_index @6926
# output_json : {'superUpTrend': False, 'price_jump': 150.97940577019799, 'time_taken': 552, 'slope': 0.2735134162503587, 'desc': 'Moving average check is FAILED and time_taken is 552', 'max_1D_decline': -14.452821507474717, 'max_5D_decline': -14.274547711439958}
# Exceeded the max_time_taken hence giving up the next_high_point search in NextLowPoint function
# No good jump identified from current low point @ index 53..  moving to next low point
# supertrend called from low_point 6500 and high_point is 6509
# Initial noise period index: 6502.
# output_json : {'superUpTrend': False, 'price_jump': 10.622464310297563, 'time_taken': 9, 'slope': 1.1802738122552847, 'desc': 'Price jump < 30%. Time taken 9 not in range 10 & None. ', 'max_1D_decline': -4.17940876656473, 'max_5D_decline': -6.809376941179281}
# supertrend called from low_point 6557 and high_point is 6564
# Initial noise period index: 6559.
# output_json : {'superUpTrend': False, 'price_jump': 13.815316882191448, 'time_taken': 7, 'slope': 1.973616697455921, 'desc': 'Price jump < 30%. Time taken 7 not in range 10 & None. ', 'max_1D_decline': -6.0651560095068735, 'max_5D_decline': -9.515643659600435}
# supertrend called from low_point 6578 and high_point is 6926
# Initial noise period index: 6631.
# output_json : {'superUpTrend': True, 'price_jump': 141.40097208069145, 'time_taken': 348, 'slope': 0.40632463241578004, 'desc': '', 'max_1D_decline': -14.452821507474717, 'max_5D_decline': -14.274547711439958}
# current_low_point index is 6578 and date is  2022-02-24 00:00:00
# Next high point found at 6926. LOW Point at 6578 Attempting to identify a stage 2 move.
# Initial noise period index: 6631.
# output_json : {'superUpTrend': True, 'price_jump': 141.40097208069145, 'time_taken': 348, 'slope': 0.40632463241578004, 'desc': '', 'max_1D_decline': -14.452821507474717, 'max_5D_decline': -14.274547711439958}
# Super uptrend confirmed.
# New record inserted   Stock_name  Start_Index  End_Index  Price_Percentage_Change     Slope  \
# 0        ITC         6578       6926               141.400972  0.406325
#
#    Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0                348 2022-02-24 2023-07-24      -14.452822      -14.274548
#
#    current_high_point
# 0                  60
# New high point identified at 60. Moving to the next analysis point.
# Analyzing from start point: 61 in extreme points.
# supertrend called from low_point 6994 and high_point is 7037
# Initial noise period index: 7001.
# Check 2 failed: MA order incorrect at index 7002.
# output_json : {'superUpTrend': False, 'price_jump': 13.149239061581977, 'time_taken': 43, 'slope': 0.3057962572460925, 'desc': 'Price jump < 30%. Moving average check is FAILED and time_taken is 43High volume on rise and low volume on decline not evidenced; upDownHighVolumeRatio is 1.125 < 1.25. ', 'max_1D_decline': -4.163014954883932, 'max_5D_decline': -6.458557588805166}
# No good jump identified from current low point @ index 63..  moving to next low point
# start_point is 61 and extreme_points length is 64
# No low point to high point left to be evaluated. Ending analysis.
# Stage 2 identification complete.
# Identified Stage 2 Potential Moves:
#   Stock_name Start_Index End_Index  Price_Percentage_Change     Slope  \
# 0        ITC        4161      4308                36.922039  0.251170
# 1        ITC        4161      4409                58.208622  0.234712
# 2        ITC        4161      4462                69.756525  0.231749
# 3        ITC        5343      5428                37.599371  0.442346
# 4        ITC        6578      6926               141.400972  0.406325
#
#   Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0               147 2012-05-08 2012-12-12      -21.170366      -22.624276
# 1               248 2012-05-08 2013-05-10      -21.170366      -22.624276
# 2               301 2012-05-08 2013-07-24      -21.170366      -22.624276
# 3                85 2017-02-27 2017-07-03      -12.556367      -12.344980
# 4               348 2022-02-24 2023-07-24      -14.452822      -14.274548
#
#   current_high_point
# 0                  6
# 1                  8
# 2                 10
# 3                 30
# 4                 60
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\1206315221.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:90: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:91: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2201745387.py:97: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
stage2_potential_df
# Out:
#   Stock_name Start_Index End_Index  Price_Percentage_Change     Slope  \
# 0        ITC        4161      4308                36.922039  0.251170
# 1        ITC        4161      4409                58.208622  0.234712
# 2        ITC        4161      4462                69.756525  0.231749
# 3        ITC        5343      5428                37.599371  0.442346
# 4        ITC        6578      6926               141.400972  0.406325
#
#   Change_Time_Taken Start_date   End_Date  max_1D_decline  max_5D_decline  \
# 0               147 2012-05-08 2012-12-12      -21.170366      -22.624276
# 1               248 2012-05-08 2013-05-10      -21.170366      -22.624276
# 2               301 2012-05-08 2013-07-24      -21.170366      -22.624276
# 3                85 2017-02-27 2017-07-03      -12.556367      -12.344980
# 4               348 2022-02-24 2023-07-24      -14.452822      -14.274548
#
#   current_high_point
# 0                  6
# 1                  8
# 2                 10
# 3                 30
# 4                 60

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Initialize the figure with subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.02, subplot_titles=('ITC.NS Historical Data', 'Volume'),
                    row_heights=[0.8, 0.2], specs=[[{"secondary_y": False}], [{"secondary_y": True}]])

# Define colors for increasing and decreasing candles
increasing_color = 'green'
decreasing_color = 'red'

# Add the candlestick chart to the first subplot with matching outline and fill colors
fig.add_trace(go.Candlestick(x=df_last_3_months['Date'],
                             open=df_last_3_months['Open'],
                             high=df_last_3_months['High'],
                             low=df_last_3_months['Low'],
                             close=df_last_3_months['Close'],
                             increasing=dict(line=dict(color=increasing_color, width=1), fillcolor=increasing_color),
                             decreasing=dict(line=dict(color=decreasing_color, width=1), fillcolor=decreasing_color),
                             name="Candlestick"), row=1, col=1)

# Add moving averages
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA200'],
                         mode='lines', name='MA200',
                         line=dict(width=1, color='blue')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA150'],
                         mode='lines', name='MA150',
                         line=dict(width=1, color='red')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA50'],
                         mode='lines', name='MA50',
                         line=dict(width=1, color='green')), row=1, col=1)

# Iterate through stage2_potential_df to add trend lines and markers
for _, row in stage2_potential_df.iterrows():
    start_date = row['Start_date']
    end_date = row['End_Date']
    start_index = row['Start_Index']
    end_index = row['End_Index']

    # Find start and end values using the index in df_last_3_months
    start_value = df_last_3_months.loc[df_last_3_months.index == start_index, 'Low'].values[0]
    end_value = df_last_3_months.loc[df_last_3_months.index == end_index, 'High'].values[0]

    # Add a line trace for this trend
    fig.add_trace(go.Scatter(x=[start_date, end_date], y=[start_value, end_value],
                             mode='lines', name=f"Trend: {start_date} to {end_date}",
                             line=dict(width=2, dash='dot')), row=1, col=1)

    # Add markers for stage 2 start and end
    fig.add_trace(go.Scatter(x=[start_date], y=[start_value],
                             mode='markers+text', name='Stage 2 Start',
                             marker=dict(color='Red', size=10),
                             text=["Stage 2 Start"],
                             textposition="bottom center"), row=1, col=1)

    fig.add_trace(go.Scatter(x=[end_date], y=[end_value],
                             mode='markers+text', name='Stage 2 End',
                             marker=dict(color='Red', size=10),
                             text=["Stage 2 End"],
                             textposition="top center"), row=1, col=1)

# Add volume trace to the second subplot
colors = ['green' if close >= open_ else 'red' for open_, close in zip(df_last_3_months['Open'], df_last_3_months['Close'])]
fig.add_trace(go.Bar(x=df_last_3_months['Date'], y=df_last_3_months['Volume'], marker_color=colors, name='Volume'), row=2, col=1)

# Customize layout without setting xaxis_type to 'category'
fig.update_layout(height=600, title='ITC.NS Historical Data (Last 3 Months) with Moving Averages, Trend Lines, and Volume',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False,
                  showlegend=False)

# Show the plot
fig.show()

# %% [markdown]
# # **Contraction**
# ---

# %% [markdown]
# #### **VCP_Correction_Magnitude_Check**

# %%
def VCP_Correction_Magnitude_Check(start_point, extreme_points):

    start_point = 2
    length_of_previous_trend_move = 0
    uptrend_correction_threshold = 40  # Example threshold value
    uptrend_retest_boundary_threshold = 0  # Example threshold value

    small_check_trend_status, small_check_no_of_skips = Uptrend_BREATHER_IDENTIFICATION(
        start_point,
        filtered_extreme_points,
        length_of_previous_trend_move,
        uptrend_correction_threshold= 10,
        uptrend_retest_boundary_threshold = 0.2)

    large_check_trend_status, large_check_no_of_skips = Uptrend_BREATHER_IDENTIFICATION(
        start_point,
        filtered_extreme_points,
        length_of_previous_trend_move,
        uptrend_correction_threshold= 40,
        uptrend_retest_boundary_threshold = 0.2)

    # print(f"Smaller check trend status: {small_check_trend_status}, Number of skips: {small_check_no_of_skips}")
    # print(f"Large check trend status: {large_check_trend_status}, Number of skips: {large_check_no_of_skips}")

    if small_check_trend_status == 'Trend Reversed' :
        if large_check_trend_status == 'Breather Continued without trend reversal or continuation' or large_check_trend_status == 'Trend Continued':
            return True

    return False

# %%
VCP_Correction_Magnitude_Check_Flag = VCP_Correction_Magnitude_Check(start_point, filtered_extreme_points)
print(f"Outcone of VCP_Correction_Magnitude_Check : {VCP_Correction_Magnitude_Check_Flag}")
# Out:
# Outcone of VCP_Correction_Magnitude_Check : True

# %% [markdown]
# #### **VCP_Zig_Zag**

# %%
def VCP_zig_zag(start_candle_index, df, percent_threshold=0,  move_relative_percent_threshold=0, absolute_threshold=0):
    """
    Generates a Zig Zag pattern by identifying a series of high and low extreme points
    in a given OHLC DataFrame.

    Parameters:
    - df: DataFrame containing OHLC data.
    - percent_threshold: The percentage movement threshold for considering an extreme point.
    - absolute_threshold: The absolute movement threshold for considering an extreme point.

    Returns:
    - A list of tuples, each containing the index of the extreme point and its type ("MAX" or "MIN").
    """
    percent_drop = 0

    # For first contraction we need to ensure percentage_threshold is set to 9.99 for else not needed
    T1_flag = True

    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])

    # Start with the first candle in the DataFrame
    if start_candle_index is None:
        start_candle_index = df.index.min()

    # Initialize the list to store the extreme points
    extreme_points = []
    start_candle_value = df.loc[start_candle_index,'High']
    # Inserting the first point since it is the first extreme point
    extreme_points.append((start_candle_index, start_candle_value, 'High'))

    current_type = None  # Keep track of the current extreme type to alternate between high and low

    while True:
        # if T1_flag:
        #     print(f"percent_threshold >>>>> {percent_threshold}")
        next_point_index, next_extreme_value, extreme_type = next_extreme_candle(df, start_candle_index, percent_threshold=percent_threshold, move_relative_percent_threshold=move_relative_percent_threshold,  absolute_threshold=absolute_threshold)
        print(f"extreme_type is {extreme_type}")
        if extreme_type == 'HIGH':
            percent_drop = (df.loc[next_point_index,'High'] -  df.loc[start_candle_index,'Low']) / df.loc[start_candle_index,'Low'] * 100
        elif extreme_type == 'LOW':
            percent_drop = (df.loc[start_candle_index,'High'] -  df.loc[next_point_index,'Low']) / df.loc[start_candle_index,'High'] * 100
        print(f"percent_threshold >>>>> {percent_threshold} || percent_drop is {percent_drop }")
        percent_threshold = 0.40 * max(percent_drop, percent_threshold)
        print(f"new percent_threshold >>>>> {percent_threshold} ")

        # Check if the next_point_index is None or if we've encountered a repeat
        if next_point_index == start_candle_index :
            # print("Encountered a repeat index")
            # Repeat index happens because that point itself is the extreme point hence it points at itsel
            if next_point_index is None:
                # print("Reached the End of dataframe")
                2==2
            break

        # Add the found extreme point to the list
        extreme_points.append((next_point_index, next_extreme_value, extreme_type))

        # Update start_candle_index for the next iteration
        start_candle_index = next_point_index

        # Check if we've reached the end of the DataFrame
        if start_candle_index == df.index.max():
            # print("Reached the end of DataFrame.")
            break

    return extreme_points

# %%
start_index = get_index('2023-07-24', df_last_3_months)

print(f"start_index is {start_index}")
vcp_extreme_points = VCP_zig_zag(
    start_index,
    df_last_3_months,
    percent_threshold = 10,
    move_relative_percent_threshold = 40,
    absolute_threshold = 0)

# vcp_extreme_points = zig_zag(
#     df_last_3_months,
#     percent_threshold = 10,
#     move_relative_percent_threshold = 0,
#     absolute_threshold = 0)
# Out:
# start_index is 6926
# New pivot low found: 436.1000061035156 at index 6953
# New pivot low found: 433.2999877929688 at index 6975
# New pivot low found: 433.1000061035156 at index 6988
# New pivot low found: 427.0499877929688 at index 6989
# New pivot low found: 425.5 at index 6994
# Threshold met. Returning pivot low index: 6994
# extreme_type is LOW
# percent_threshold >>>>> 10 || percent_drop is 14.848911425739452
# new percent_threshold >>>>> 5.939564570295781
# New pivot high found: 457.7999877929688 at index 7016
# New pivot high found: 464.5 at index 7017
# New pivot high found: 464.7999877929688 at index 7018
# New pivot high found: 467.8999938964844 at index 7033
# New pivot high found: 469.9500122070313 at index 7034
# New pivot high found: 471.3500061035156 at index 7035
# New pivot high found: 480.7000122070313 at index 7036
# New pivot high found: 481.4500122070313 at index 7037
# Threshold met. Returning pivot high index: 7037
# extreme_type is HIGH
# percent_threshold >>>>> 5.939564570295781 || percent_drop is 13.149239061581977
# new percent_threshold >>>>> 5.259695624632791
# New pivot low found: 436.5499877929688 at index 7058
# New pivot low found: 429.5 at index 7059
# New pivot low found: 408.6000061035156 at index 7061
# extreme_type is LOW
# percent_threshold >>>>> 5.259695624632791 || percent_drop is 15.131374858536509
# new percent_threshold >>>>> 6.052549943414604
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\3646839889.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ayann\AppData\Local\Temp\ipykernel_8624\2429544573.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
vcp_extreme_points
# Out:
# [(6926, 499.7000122070313, 'High'),
#  (6994, 425.5, 'LOW'),
#  (7037, 481.4500122070313, 'HIGH'),
#  (7061, 408.6000061035156, 'LOW')]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Initialize the figure with subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.02, subplot_titles=('ITC.NS Historical Data', 'Volume'),
                    row_heights=[0.8, 0.2], specs=[[{"secondary_y": False}], [{"secondary_y": True}]])

# Define colors for increasing and decreasing candles
increasing_color = 'green'
decreasing_color = 'red'

# Add the candlestick chart to the first subplot with matching outline and fill colors
fig.add_trace(go.Candlestick(x=df_last_3_months['Date'],
                             open=df_last_3_months['Open'],
                             high=df_last_3_months['High'],
                             low=df_last_3_months['Low'],
                             close=df_last_3_months['Close'],
                             increasing=dict(line=dict(color=increasing_color, width=1), fillcolor=increasing_color),
                             decreasing=dict(line=dict(color=decreasing_color, width=1), fillcolor=decreasing_color),
                             name="Candlestick"), row=1, col=1)

# Function to extract date and value for plotting
def extract_date_value(points, df):
    # Corrected function to ensure 'idx' is defined in both comprehensions
    dates = [df.loc[idx, 'Date'] for idx, value, point_type in points if idx in df.index]
    values = [value for idx, value, point_type in points if idx in df.index]
    return dates, values

# VCP Extreme Points (with trend lines)
dates, values = extract_date_value(vcp_extreme_points, df_last_3_months)
fig.add_trace(go.Scatter(x=dates, y=values, mode='lines+markers',
                         line=dict(color='Blue', width=2),
                         marker=dict(color='LightSkyBlue', size=1),
                         name='Original Trend'))


# Add moving averages
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA200'],
                         mode='lines', name='MA200',
                         line=dict(width=1, color='blue')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA150'],
                         mode='lines', name='MA150',
                         line=dict(width=1, color='red')), row=1, col=1)
fig.add_trace(go.Scatter(x=df_last_3_months['Date'], y=df_last_3_months['MA50'],
                         mode='lines', name='MA50',
                         line=dict(width=1, color='green')), row=1, col=1)

# Iterate through stage2_potential_df to add trend lines and markers
for _, row in stage2_potential_df.iterrows():
    start_date = row['Start_date']
    end_date = row['End_Date']
    start_index = row['Start_Index']
    end_index = row['End_Index']

    print(f"start_index >> {start_index}")

    # Find start and end values using the index in df_last_3_months
    start_value = df_last_3_months.loc[df_last_3_months.index == start_index, 'Low'].values[0]
    end_value = df_last_3_months.loc[df_last_3_months.index == end_index, 'High'].values[0]

    # Add a line trace for this trend
    fig.add_trace(go.Scatter(x=[start_date, end_date], y=[start_value, end_value],
                             mode='lines', name=f"Trend: {start_date} to {end_date}",
                             line=dict(color = 'Red', width=2, dash='dot')), row=1, col=1)

    # Add markers for stage 2 start and end
    fig.add_trace(go.Scatter(x=[start_date], y=[start_value],
                             mode='markers+text', name='Stage 2 Start',
                             marker=dict(color='Red', size=10),
                             text=["Stage 2 Start"],
                             textposition="bottom center"), row=1, col=1)

    fig.add_trace(go.Scatter(x=[end_date], y=[end_value],
                             mode='markers+text', name='Stage 2 End',
                             marker=dict(color='Red', size=10),
                             text=["Stage 2 End"],
                             textposition="top center"), row=1, col=1)

# Add volume trace to the second subplot
colors = ['green' if close >= open_ else 'red' for open_, close in zip(df_last_3_months['Open'], df_last_3_months['Close'])]
fig.add_trace(go.Bar(x=df_last_3_months['Date'], y=df_last_3_months['Volume'], marker_color=colors, name='Volume'), row=2, col=1)

# Customize layout without setting xaxis_type to 'category'
fig.update_layout(height=600, title='ITC.NS Historical Data (Last 3 Months) with Moving Averages, Trend Lines, and Volume',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=False,
                  showlegend=False)

# Show the plot
fig.show()
# Out:
# start_index >> 4161
# start_index >> 4161
# start_index >> 4161
# start_index >> 5343
# start_index >> 6578
